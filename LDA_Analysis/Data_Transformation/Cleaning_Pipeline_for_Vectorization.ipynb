# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import pickle

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nborders/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nborders/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop = set(stopwords.words('english'))
got_stop = ['[spoilers]', '[deleted]', 'nan', '[removed]', '[spoiler]', 'deleted', '[Spoilers', 'Main]', 'Spoilers', 'Main', 'removed', 'spoiler', '[All', 'Spoilers]', 'all', 'spoilers', '[NO SPOILER]', 'no spoiler', '[SPOLER]', '(Spoilers', 'Main)', 'spoler', '[Spoilers]', '[SPOILERS]', 'SPOILERS', 'MAIN]', 'MAIN', 'extended)', 'extended', 'Production)', 'Production', 'EXTENDED]', 'EXTENDED', '[NO', 'SPOILERS]', 'NO', '*Spoilers', 'Ahead*', 'Ahead', 'Extended]', 'Extended', '{SPOILER}', 'SPOILER', '[No', 'Spoiler]', 'No', 'Spoiler', '(NO', 'SPOILERS)', 'MAIN)', '(SPOILERS', '(no', 'spoilers)', '[SPOILERS', 'Extended)']
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

# %%
got_reddit = pickle.load( open( "./Data/got_reddit_cleaned_monday.pkl", "rb" ) )
asoiaf_reddit = pickle.load( open( "./Data/soiaf_reddit_cleaned_monday.pkl", "rb" ) )
freefolk_reddit = pickle.load( open( "./Data/freefolk_reddit_cleaned_monday.pkl", "rb" ) )

# %%
def remove_all_punctuation(comment):
    punct_list = [i for i in string.punctuation]
    
    while re.findall(r'\\n', comment) != []:
        comment = comment.replace(re.search(r'\\n', comment)[0], '')
    while re.findall(r'\\t', comment) != []:
        comment = comment.replace(re.search(r'\\t', comment)[0], '')
    while re.findall(r'\\u.{4}', comment) != []:
        comment = comment.replace(re.search(r'\\u.{4}', comment)[0], '')
    
    for i in punct_list:
        comment = comment.replace(i, ' ')
    
    return comment

# %%
def remove_punctuation(comment):
    punct_list = [i for i in string.punctuation]
    for i in punct_list:
        comment = comment.replace(i, ' ')
    return comment

# %%
def trim_and_lower(comment):
    arr = comment.split()
    comment = " ".join(arr).lower()
    return comment

# %%
def remove_stops(comment):
    stop_free = [i for i in comment.split() if i not in stop]
    got_stop_free = " ".join([i for i in stop_free if i not in got_stop])
    return got_stop_free

# %%
def lemmatize(comment):
    return " ".join(lemma.lemmatize(word) for word in comment.split())

# %%
def remove_num(comment):
    return ''.join([char for char in comment if not char.isdigit()])

# %%
words = set(nltk.corpus.words.words())

def clean_sent(comment):
    return " ".join(w for w in nltk.wordpunct_tokenize(comment) \
     if w.lower() in words or w.istitle())

clean_sent('aaaaaaaaaaaaarghaoakwbduspwmnalyu')
# Out:
# ''

# %%
got_reddit['clean'] = got_reddit['body'].apply(remove_all_punctuation)
got_reddit['clean'] = got_reddit['clean'].apply(clean_sent)
got_reddit['clean'] = got_reddit['clean'].apply(trim_and_lower)
got_reddit['clean'] = got_reddit['clean'].apply(remove_num)
got_reddit['clean'] = got_reddit['clean'].apply(remove_stops)
got_reddit['clean'] = got_reddit['clean'].apply(lemmatize)

asoiaf_reddit['clean'] = asoiaf_reddit['body'].apply(remove_all_punctuation)
asoiaf_reddit['clean'] = asoiaf_reddit['clean'].apply(clean_sent)
asoiaf_reddit['clean'] = asoiaf_reddit['clean'].apply(trim_and_lower)
asoiaf_reddit['clean'] = asoiaf_reddit['clean'].apply(remove_num)
asoiaf_reddit['clean'] = asoiaf_reddit['clean'].apply(remove_stops)
asoiaf_reddit['clean'] = asoiaf_reddit['clean'].apply(lemmatize)

freefolk_reddit['clean'] = freefolk_reddit['body'].apply(remove_all_punctuation)
freefolk_reddit['clean'] = freefolk_reddit['clean'].apply(clean_sent)
freefolk_reddit['clean'] = freefolk_reddit['clean'].apply(trim_and_lower)
freefolk_reddit['clean'] = freefolk_reddit['clean'].apply(remove_num)
freefolk_reddit['clean'] = freefolk_reddit['clean'].apply(remove_stops)
freefolk_reddit['clean'] = freefolk_reddit['clean'].apply(lemmatize)

# %%
#pickle.dump(freefolk_reddit, open("freefolk_reddit_ready_vector_monday.pkl", "wb" ) )
#pickle.dump(asoiaf_reddit, open("soiaf_reddit_ready_vector_monday.pkl", "wb" ) )
#pickle.dump(got_reddit, open("got_reddit_ready_vector_monday.pkl", "wb" ) )

# %%
got = pickle.load( open( "./Data/got_reddit_ready_vector_monday.pkl", "rb" ) )
#asoiaf = pickle.load( open( "./Data/soiaf_reddit_ready_vector.pkl", "rb" ) )
#freefolk = pickle.load( open( "./Data/freefolk_reddit_ready_vector.pkl", "rb" ) )

# %%
# cleaning each of subreddits separately so we can remove words which appear too frequently and not often enough

# %%
#GOT

count_dict_GOT = {}

for doc in got['clean']:
    for word in doc.split():
        if word in count_dict_GOT.keys():
            count_dict_GOT[word] +=1
        else:
            count_dict_GOT[word] = 1

# %%
count_dict_GOT
# Out:
# {'could': 18287,
#  'would': 34323,
#  'watch': 8842,
#  'wait': 2165,
#  'season': 28368,
#  'curious': 750,
#  'see': 18452,
#  'chronological': 20,
#  'order': 1806,
#  'winter': 3130,
#  'coming': 4398,
#  'baelor': 177,
#  'blackwater': 489,
#  'rain': 367,
#  'castamere': 282,
#  'mhysa': 72,
#  'lion': 492,
#  'rose': 248,
#  'mountain': 2611,
#  'viper': 68,
#  'child': 3452,
#  'hardhome': 598,
#  'mother': 1906,
#  'mercy': 531,
#  'door': 1456,
#  'battle': 16566,
#  'bastard': 1437,
#  'wind': 602,
#  'spoil': 306,
#  'war': 5966,
#  'dragon': 14838,
#  'wolf': 952,
#  'hard': 2022,
#  'come': 9183,
#  'list': 1565,
#  'many': 9213,
#  'great': 6349,
#  'people': 21554,
#  'limited': 275,
#  'time': 18809,
#  'hope': 3608,
#  'helpful': 104,
#  'spark': 61,
#  'conversation': 1047,
#  'picked': 288,
#  'glass': 1402,
#  'dagger': 2120,
#  'found': 2379,
#  'mexico': 13,
#  'taking': 1968,
#  'tour': 123,
#  'chichén': 2,
#  'itzá': 2,
#  'obsidian': 154,
#  'ready': 1463,
#  'book': 2747,
#  'question': 3642,
#  'man': 5335,
#  'without': 4435,
#  'face': 4354,
#  'dead': 13542,
#  'crow': 287,
#  'know': 17461,
#  'talking': 2158,
#  'except': 1315,
#  'one': 30006,
#  'help': 4100,
#  'got': 19366,
#  'enough': 3566,
#  'binge': 228,
#  'must': 2595,
#  'premiere': 989,
#  'goal': 905,
#  'total': 618,
#  'top': 1624,
#  'decide': 578,
#  'work': 3483,
#  'life': 5533,
#  'general': 1076,
#  'able': 3342,
#  'give': 4127,
#  'complete': 1262,
#  'series': 7702,
#  'definitely': 1520,
#  'revisit': 37,
#  'best': 6071,
#  'show': 25731,
#  'came': 2880,
#  'feel': 7418,
#  'start': 3213,
#  'unfortunately': 292,
#  'leave': 1951,
#  'incredible': 804,
#  'fill': 331,
#  'aware': 561,
#  'lot': 6756,
#  'tend': 115,
#  'contain': 131,
#  'significant': 531,
#  'though': 3904,
#  'surprise': 995,
#  'episode': 40685,
#  'world': 5348,
#  'westeros': 5714,
#  'begin': 781,
#  'groundwork': 43,
#  'laid': 307,
#  'still': 11690,
#  'unsure': 121,
#  'read': 2751,
#  'course': 1941,
#  'automatic': 16,
#  'inclusion': 23,
#  'significance': 339,
#  'first': 11747,
#  'surely': 630,
#  'made': 10391,
#  'fan': 2815,
#  'realize': 1077,
#  'nobody': 1165,
#  'safe': 1242,
#  'early': 914,
#  'tyrion': 13565,
#  'tywin': 1323,
#  'develop': 196,
#  'deal': 1345,
#  'lord': 4707,
#  'walder': 269,
#  'frey': 697,
#  'robb': 952,
#  'marrying': 127,
#  'back': 12904,
#  'haunt': 18,
#  'anyone': 8860,
#  'wall': 5290,
#  'jon': 39862,
#  'important': 2940,
#  'mormont': 1599,
#  'form': 866,
#  'valyrian': 1108,
#  'steel': 1734,
#  'sword': 3923,
#  'challenge': 202,
#  'grow': 475,
#  'daenerys': 12180,
#  'upon': 1020,
#  'cursed': 64,
#  'magic': 2058,
#  'save': 2981,
#  'drogo': 779,
#  'death': 10368,
#  'finally': 3377,
#  'ned': 4096,
#  'stark': 8107,
#  'everyone': 9936,
#  'invincible': 134,
#  'game': 16570,
#  'throne': 23419,
#  'get': 15551,
#  'joffrey': 1128,
#  'evil': 2027,
#  'ruler': 1452,
#  'unpack': 8,
#  'likely': 2437,
#  'major': 2328,
#  'role': 1660,
#  'stratosphere': 2,
#  'fire': 8494,
#  'blood': 2194,
#  'penultimate': 122,
#  'masterpiece': 226,
#  'set': 2846,
#  'perspective': 762,
#  'future': 2081,
#  'forced': 842,
#  'aftermath': 309,
#  'stage': 228,
#  'remainder': 112,
#  'new': 6538,
#  'kill': 13312,
#  'spare': 163,
#  'suffering': 268,
#  'sad': 1420,
#  'powerful': 1222,
#  'scene': 10140,
#  'funeral': 121,
#  'pyre': 107,
#  'shown': 1704,
#  'next': 6533,
#  'day': 4304,
#  'three': 4569,
#  'lovely': 84,
#  'old': 2907,
#  'god': 2976,
#  'another': 4823,
#  'turning': 872,
#  'point': 7249,
#  'story': 8971,
#  'theon': 4279,
#  'winterfell': 10468,
#  'embarrassing': 35,
#  'execution': 508,
#  'ser': 1382,
#  'rodrik': 19,
#  'allow': 515,
#  'bolton': 490,
#  'son': 1993,
#  'sound': 854,
#  'like': 31535,
#  'nice': 1152,
#  'guy': 2308,
#  'assist': 85,
#  'ygritte': 337,
#  'yes': 2334,
#  'please': 2590,
#  'stolen': 139,
#  'importantly': 291,
#  'completely': 2913,
#  'king': 42630,
#  'landing': 9165,
#  'epic': 1421,
#  'way': 14801,
#  'watching': 4981,
#  'heart': 2372,
#  'racing': 30,
#  'cunning': 137,
#  'worth': 899,
#  'battlefield': 448,
#  'cersei': 20618,
#  'little': 6003,
#  'bit': 3140,
#  'compassion': 97,
#  'left': 5983,
#  'davos': 1831,
#  'useless': 833,
#  'assistant': 25,
#  'tension': 579,
#  'rise': 672,
#  'around': 5217,
#  'within': 1142,
#  'lanisters': 26,
#  'baratheon': 1420,
#  'result': 704,
#  'valar': 280,
#  'morghulus': 1,
#  'hero': 1802,
#  'hand': 3716,
#  'sansa': 10650,
#  'marriage': 439,
#  'much': 10800,
#  'sister': 1328,
#  'brienne': 4782,
#  'escort': 23,
#  'jamie': 5504,
#  'arya': 25017,
#  'special': 739,
#  'coin': 355,
#  'jaqen': 590,
#  'sweet': 528,
#  'revenge': 977,
#  'qarth': 105,
#  'white': 10402,
#  'march': 562,
#  'towards': 2078,
#  'night': 34797,
#  'encampment': 10,
#  'impossible': 623,
#  'ignore': 332,
#  'ended': 2139,
#  'fantastic': 477,
#  'material': 637,
#  'felt': 3262,
#  'today': 1837,
#  'discussion': 1207,
#  'tarth': 421,
#  'foreshadow': 197,
#  'relationship': 954,
#  'end': 14365,
#  'margaery': 207,
#  'tyrael': 2,
#  'build': 1335,
#  'distrust': 76,
#  'commander': 730,
#  'control': 1434,
#  'unsullied': 2715,
#  'unique': 215,
#  'barter': 2,
#  'beyond': 1591,
#  'sucker': 22,
#  'horizon': 57,
#  'zero': 384,
#  'dawn': 404,
#  'kissed': 29,
#  'hopefully': 499,
#  'think': 26398,
#  'worthy': 241,
#  'otherwise': 600,
#  'might': 5116,
#  'become': 3569,
#  'alone': 1529,
#  'make': 10657,
#  'want': 7978,
#  'filled': 385,
#  'unwelcome': 9,
#  'torture': 142,
#  'growing': 305,
#  'excellent': 288,
#  'received': 309,
#  'publicity': 16,
#  'north': 7651,
#  'bran': 26591,
#  'true': 5584,
#  'potential': 922,
#  'hodor': 1387,
#  'thunder': 20,
#  'spreading': 91,
#  'influence': 375,
#  'yunkai': 119,
#  'rivalry': 29,
#  'pledge': 101,
#  'real': 4516,
#  'reason': 4484,
#  'red': 4263,
#  'wedding': 1153,
#  'single': 1735,
#  'kept': 1118,
#  'far': 4314,
#  'drastic': 59,
#  'event': 548,
#  'waiting': 1680,
#  'patiently': 37,
#  'moment': 4923,
#  'forged': 298,
#  'never': 8847,
#  'innocent': 1204,
#  'girl': 1995,
#  'starting': 851,
#  'right': 8231,
#  'pain': 558,
#  'given': 2664,
#  'justice': 664,
#  'purple': 85,
#  'ramsay': 631,
#  'offer': 356,
#  'considered': 483,
#  'moat': 119,
#  'cailin': 42,
#  'insulting': 80,
#  'play': 2330,
#  'tied': 313,
#  'follow': 1077,
#  'brilliant': 479,
#  'conclusion': 829,
#  'u': 6832,
#  'massive': 942,
#  'change': 2397,
#  'momentum': 58,
#  'place': 3394,
#  'watcher': 155,
#  'entire': 4608,
#  'attack': 2335,
#  'wildlings': 358,
#  'castle': 2382,
#  'black': 1651,
#  'display': 178,
#  'action': 1126,
#  'olly': 81,
#  'damn': 1317,
#  'mortally': 82,
#  'serve': 615,
#  'shift': 289,
#  'finale': 2721,
#  'intense': 293,
#  'anticipation': 162,
#  'ahead': 660,
#  'chain': 298,
#  'away': 4117,
#  'realizing': 287,
#  'leadership': 241,
#  'meereen': 388,
#  'easy': 1165,
#  'eyed': 2947,
#  'raven': 4005,
#  'remains': 433,
#  'mance': 189,
#  'rayder': 83,
#  'capture': 342,
#  'rather': 1779,
#  'dying': 1941,
#  'qybene': 1,
#  'concerned': 295,
#  'receive': 128,
#  'hit': 1285,
#  'reality': 585,
#  'strangling': 21,
#  'woman': 2064,
#  'thought': 8969,
#  'killing': 5417,
#  'father': 2489,
#  'prideful': 10,
#  'pose': 76,
#  'easiest': 66,
#  'easily': 1469,
#  'sequence': 555,
#  'absolutely': 1747,
#  'edge': 436,
#  'seat': 318,
#  'experience': 820,
#  'seeing': 2918,
#  'sheer': 201,
#  'power': 4297,
#  'long': 7740,
#  'rest': 2469,
#  'plenty': 440,
#  'character': 12207,
#  'development': 1174,
#  'rage': 575,
#  'building': 959,
#  'inside': 1424,
#  'septum': 46,
#  'pushing': 243,
#  'confess': 24,
#  'well': 7853,
#  'transformation': 174,
#  'faceless': 1132,
#  'arc': 3547,
#  'continue': 796,
#  'mareen': 15,
#  'emerge': 79,
#  'dance': 420,
#  'last': 16637,
#  'truly': 1944,
#  'buildup': 287,
#  'braavos': 278,
#  'prepare': 382,
#  'wide': 177,
#  'hatred': 272,
#  'stannis': 1212,
#  'daughter': 609,
#  'burned': 1288,
#  'fate': 1061,
#  'drogon': 5256,
#  'opportunity': 714,
#  'working': 677,
#  'count': 470,
#  'quick': 1038,
#  'harpy': 105,
#  'vital': 95,
#  'myrcella': 121,
#  'lannister': 4094,
#  'ellaria': 238,
#  'blinded': 84,
#  'meryn': 77,
#  'trent': 1,
#  'approach': 373,
#  'dothraki': 3686,
#  'horde': 462,
#  'leaving': 1183,
#  'open': 1233,
#  'walk': 773,
#  'shame': 393,
#  'even': 15339,
#  'knowing': 1331,
#  'incredibly': 555,
#  'tissue': 12,
#  'jorah': 3926,
#  'leaf': 957,
#  'revealing': 234,
#  'euron': 4866,
#  'chosen': 420,
#  'salt': 369,
#  'actress': 187,
#  'negatively': 22,
#  'family': 3498,
#  'knowledge': 704,
#  'shattering': 56,
#  'hold': 2102,
#  'gave': 2176,
#  'ending': 7825,
#  'deserved': 621,
#  'written': 1331,
#  'bulk': 70,
#  'rickon': 366,
#  'unfortunate': 84,
#  'arrival': 227,
#  'knight': 1670,
#  'vale': 811,
#  'wun': 157,
#  'group': 830,
#  'hungry': 222,
#  'dog': 631,
#  'multiple': 1064,
#  'dazed': 9,
#  'quickly': 976,
#  'mental': 246,
#  'exhaustion': 22,
#  'light': 3667,
#  'seven': 2788,
#  'brilliantly': 69,
#  'television': 681,
#  'history': 2531,
#  'quarter': 54,
#  'destruction': 892,
#  'masterwork': 6,
#  'cinematography': 475,
#  'music': 1543,
#  'lyanna': 1770,
#  'oh': 1626,
#  'speech': 416,
#  'learn': 774,
#  'snow': 7069,
#  'birth': 597,
#  'head': 2850,
#  'west': 400,
#  'upcoming': 491,
#  'miss': 923,
#  'winterfall': 19,
#  'sometimes': 621,
#  'awkward': 198,
#  'reunion': 523,
#  'dragonstone': 850,
#  'mine': 562,
#  'strong': 1266,
#  'nothing': 4568,
#  'compare': 204,
#  'roseroad': 6,
#  'brutal': 356,
#  'assault': 139,
#  'caravan': 11,
#  'understanding': 365,
#  'terrifying': 230,
#  'risen': 132,
#  'viserion': 1714,
#  'uncertain': 43,
#  'brought': 2011,
#  'ally': 688,
#  'look': 4663,
#  'rescue': 280,
#  'cost': 508,
#  'include': 334,
#  'final': 6407,
#  'previous': 1415,
#  'happen': 4534,
#  'littlefinger': 1407,
#  'unable': 340,
#  'talk': 2079,
#  'situation': 909,
#  'jons': 227,
#  'claim': 2009,
#  'iron': 6824,
#  'clear': 1614,
#  'color': 364,
#  'also': 12789,
#  'boat': 323,
#  'lady': 1702,
#  'dream': 735,
#  'caught': 806,
#  'need': 6182,
#  'subscription': 137,
#  'six': 388,
#  'wonder': 1034,
#  'robin': 278,
#  'arryn': 439,
#  'ever': 5531,
#  'better': 5776,
#  'bow': 431,
#  'arrow': 456,
#  'samwell': 773,
#  'tarly': 805,
#  'sure': 5318,
#  'someone': 5752,
#  'probably': 4647,
#  'sam': 4672,
#  'brother': 2956,
#  'affect': 202,
#  'find': 3589,
#  'assuming': 622,
#  'together': 3048,
#  'dickon': 107,
#  'feller': 1,
#  'take': 7398,
#  'side': 3527,
#  'big': 4278,
#  'move': 1637,
#  'obviously': 1832,
#  'bigger': 801,
#  'going': 13755,
#  'kind': 2934,
#  'dispute': 30,
#  'bingo': 181,
#  'living': 3483,
#  'defeat': 1675,
#  'enemy': 1626,
#  'weapon': 1387,
#  'remember': 2981,
#  'ice': 3745,
#  'said': 6260,
#  'two': 7233,
#  'wight': 2829,
#  'unlikely': 463,
#  'problem': 1663,
#  'brittle': 23,
#  'pierce': 70,
#  'hide': 440,
#  'expect': 1421,
#  'scorpion': 649,
#  'bolt': 163,
#  'breaking': 794,
#  'tip': 112,
#  'break': 1416,
#  'impact': 519,
#  'perhaps': 1881,
#  'something': 9684,
#  'seem': 2454,
#  'explanation': 839,
#  'meet': 877,
#  'demise': 257,
#  'impression': 191,
#  'crew': 490,
#  'couple': 1507,
#  'currently': 604,
#  'home': 1412,
#  'ironborn': 244,
#  'starks': 2341,
#  'say': 6355,
#  'pyke': 72,
#  'mark': 510,
#  'ideal': 144,
#  'scenario': 438,
#  'yara': 1023,
#  'e': 2263,
#  'g': 465,
#  'suddenly': 1133,
#  'capable': 492,
#  'amazing': 2366,
#  'ship': 562,
#  'return': 1454,
#  'immediately': 908,
#  'band': 208,
#  'loyal': 743,
#  'proclaiming': 29,
#  'spirit': 166,
#  'imagine': 1519,
#  'selling': 90,
#  'example': 1223,
#  'done': 4798,
#  'legend': 397,
#  'speak': 505,
#  'inner': 131,
#  'charge': 1710,
#  'dagmer': 17,
#  'put': 3386,
#  'raping': 88,
#  'since': 6550,
#  'balon': 84,
#  'deferent': 1,
#  'wanting': 533,
#  'invite': 39,
#  'mutiny': 29,
#  'captain': 175,
#  'present': 904,
#  'respect': 819,
#  'least': 3955,
#  'speed': 285,
#  'pay': 773,
#  'price': 229,
#  'captaincy': 1,
#  'wrath': 63,
#  'whoever': 392,
#  'helping': 409,
#  'training': 766,
#  'advantageous': 15,
#  'self': 809,
#  'interested': 670,
#  'pirate': 164,
#  'advantage': 435,
#  'military': 687,
#  'genius': 285,
#  'astound': 1,
#  'impress': 34,
#  'inspire': 72,
#  'dany': 27566,
#  'used': 3196,
#  'path': 710,
#  'greyjoys': 127,
#  'highest': 184,
#  'regard': 142,
#  'interesting': 2290,
#  'trying': 3639,
#  'figure': 780,
#  'manipulate': 168,
#  'teaching': 74,
#  'prodigal': 3,
#  'green': 1271,
#  'wondering': 1192,
#  'else': 7059,
#  'position': 809,
#  'tentatively': 2,
#  'prediction': 1743,
#  'se': 5741,
#  'meeting': 639,
#  'following': 1129,
#  'murder': 641,
#  'mossador': 16,
#  'heavy': 494,
#  'accent': 42,
#  'name': 2927,
#  'pronounced': 33,
#  'die': 9748,
#  'heiress': 4,
#  'looking': 2784,
#  'spiral': 405,
#  'sorry': 1588,
#  'posted': 801,
#  'delete': 72,
#  'post': 3190,
#  'feast': 276,
#  'go': 12389,
#  'rape': 254,
#  'suppose': 293,
#  'really': 13515,
#  'matter': 1965,
#  'baby': 1780,
#  'maybe': 8009,
#  'visit': 177,
#  'tonight': 2553,
#  'strange': 485,
#  'considering': 887,
#  'sensitivity': 2,
#  'topic': 178,
#  'listening': 284,
#  'facing': 385,
#  'cow': 35,
#  'street': 321,
#  'riot': 48,
#  'robert': 1983,
#  'pride': 166,
#  'bobby': 134,
#  'b': 898,
#  'victory': 602,
#  'trident': 93,
#  'throwing': 368,
#  'leech': 15,
#  'saying': 3518,
#  'usurper': 88,
#  'literal': 435,
#  'calling': 574,
#  'beginning': 1736,
#  'appearance': 333,
#  'correcting': 8,
#  'grammar': 69,
#  'main': 3932,
#  'force': 1325,
#  'voice': 560,
#  'carry': 295,
#  'discovery': 41,
#  'lineage': 478,
#  'sending': 452,
#  'throughout': 1708,
#  'incest': 395,
#  'based': 1463,
#  'exchange': 224,
#  'weird': 932,
#  'piss': 112,
#  'past': 4394,
#  'necessarily': 348,
#  'explore': 146,
#  'actually': 6472,
#  'personally': 1255,
#  'love': 8168,
#  'rhaegar': 1099,
#  'dialogue': 789,
#  'prepared': 401,
#  'fast': 900,
#  'yet': 4156,
#  'rewatching': 130,
#  'resurrection': 265,
#  'poorly': 345,
#  'opinion': 2539,
#  'melisandre': 2884,
#  'perform': 78,
#  'fine': 1070,
#  'beric': 1748,
#  'thoros': 188,
#  'source': 850,
#  'washing': 20,
#  'body': 1256,
#  'reveal': 821,
#  'throw': 695,
#  'rag': 8,
#  'bring': 1930,
#  'ceremony': 69,
#  'targaryen': 5008,
#  'making': 3025,
#  'speculate': 106,
#  'former': 331,
#  'wasted': 333,
#  'hour': 642,
#  'drive': 301,
#  'line': 2933,
#  'em': 170,
#  'promo': 68,
#  'official': 358,
#  'version': 1009,
#  'khaleesi': 416,
#  'theory': 9303,
#  'busy': 197,
#  'replica': 29,
#  'specifically': 575,
#  'york': 69,
#  'tomorrow': 474,
#  'sit': 1412,
#  'idea': 2675,
#  'specific': 446,
#  'location': 350,
#  'fort': 47,
#  'totten': 6,
#  'drink': 464,
#  'corresponding': 14,
#  'screen': 1565,
#  'footage': 180,
#  'bother': 262,
#  'crazy': 1684,
#  'men': 4421,
#  'syrio': 401,
#  'dancing': 119,
#  'master': 839,
#  'pick': 617,
#  'lying': 329,
#  'ground': 1608,
#  'fight': 7313,
#  'whole': 5843,
#  'wooden': 159,
#  'obvious': 1558,
#  'rickard': 65,
#  'running': 1122,
#  'straight': 956,
#  'weaving': 16,
#  'benjen': 461,
#  'giving': 1549,
#  'horse': 1531,
#  'instead': 3786,
#  'getting': 3721,
#  'anybody': 738,
#  'anything': 4043,
#  'similar': 1637,
#  'kinda': 121,
#  'thorough': 22,
#  'recap': 537,
#  'job': 1240,
#  'seen': 6628,
#  'highly': 367,
#  'recommend': 144,
#  'everything': 5547,
#  'check': 681,
#  'channel': 267,
#  'film': 416,
#  'cram': 25,
#  'good': 10673,
#  'explaining': 259,
#  'depth': 362,
#  'watched': 2092,
#  'v': 1797,
#  'gc': 2,
#  'historical': 180,
#  'x': 610,
#  'house': 3650,
#  'unboxing': 2,
#  'video': 1652,
#  'edition': 176,
#  'sneaker': 5,
#  'adidas': 8,
#  'difference': 538,
#  'pretty': 3969,
#  'close': 2076,
#  'closer': 392,
#  'mainly': 270,
#  'cutting': 261,
#  'boring': 379,
#  'lesser': 108,
#  'viserys': 510,
#  'golden': 2071,
#  'crown': 723,
#  'eating': 228,
#  'later': 2087,
#  'ten': 304,
#  'informed': 79,
#  'deformed': 18,
#  'human': 1880,
#  'included': 369,
#  'scale': 436,
#  'therefore': 670,
#  'appreciation': 215,
#  'bellagio': 31,
#  'la': 278,
#  'vega': 70,
#  'fountain': 31,
#  'absolute': 544,
#  'jaime': 9604,
#  'bath': 55,
#  'trial': 549,
#  'combat': 732,
#  'earlier': 53,
#  'saw': 4599,
#  'stuck': 439,
#  'awesome': 1167,
#  'favorite': 2331,
#  'praise': 154,
#  'triangle': 29,
#  'mural': 23,
#  'cat': 355,
#  'react': 363,
#  'related': 528,
#  'care': 2009,
#  'ago': 1752,
#  'trailer': 1106,
#  'extra': 490,
#  'breakdown': 174,
#  'road': 267,
#  'trip': 150,
#  'queen': 7468,
#  'wrong': 3028,
#  'maisie': 433,
#  'williams': 332,
#  'harder': 284,
#  'mad': 6291,
#  'max': 27,
#  'hello': 329,
#  'dumb': 932,
#  'drawing': 454,
#  'preparation': 178,
#  'dark': 2101,
#  'full': 2911,
#  'jojen': 161,
#  'cartoon': 53,
#  'drew': 237,
#  'hail': 209,
#  'screw': 134,
#  'redd': 1432,
#  'foretold': 54,
#  'undying': 308,
#  'room': 1721,
#  'hut': 32,
#  'tragedy': 339,
#  'loss': 538,
#  'husband': 303,
#  'khal': 431,
#  'born': 1154,
#  'second': 2749,
#  'lost': 3655,
#  'ultimate': 911,
#  'warlock': 33,
#  'keep': 5054,
#  'presence': 232,
#  'roll': 329,
#  'fitting': 642,
#  'almost': 3180,
#  'tempting': 15,
#  'covered': 428,
#  'ash': 854,
#  'poetic': 451,
#  'symbolic': 192,
#  'choice': 1199,
#  'sacrifice': 1059,
#  'already': 4593,
#  'pointed': 375,
#  'bad': 5408,
#  'may': 5038,
#  'thinking': 3042,
#  'entirely': 681,
#  'meh': 37,
#  'hi': 363,
#  'loras': 111,
#  'tyrell': 349,
#  'renly': 236,
#  'spot': 577,
#  'score': 394,
#  'overweight': 3,
#  'preview': 741,
#  'hair': 848,
#  'stylist': 3,
#  'duplicate': 8,
#  'strictly': 59,
#  'cause': 1450,
#  'renlys': 1,
#  'somehow': 1768,
#  'figured': 468,
#  'killer': 278,
#  'part': 4210,
#  'tyrells': 138,
#  'coincidence': 301,
#  'tall': 160,
#  'blonde': 134,
#  'chick': 25,
#  'mishap': 2,
#  'free': 1832,
#  'country': 294,
#  'beware': 52,
#  'alive': 3519,
#  'every': 4935,
#  ...}

# %%
### These are helper functions not used in the current cleaning process, saved for reference to potentially be used in further cleaning efforts.

#low_value = 15
#for key in count_dict.keys():
    #if count_dict[key] < low_value: 
#corpus = [doc.split() for doc in got['clean']]
#for item in got['clean']:
    #got['clean_list'][item] = item.split()
    #corpus = [word for word in corpus if word not in bad_words]

# %%
low_value = 20
bad_words_GOT = [key for key in count_dict_GOT.keys() if count_dict_GOT[key] < low_value]

# %%
high_value = 40000
bad_high_words_GOT = [key for key in count_dict_GOT.keys() if count_dict_GOT[key] > high_value]

# %%
got.shape
# Out:
# (153179, 7)

# %%
corpus = [doc.split() for doc in got['clean']]

# %%
#a list of lists where each document is a string broken into a list of words
cleaner_corpus_GOT = []
for document in corpus:
    cleaner_corpus_GOT.append([word for word in document if word not in bad_words_GOT])

# %%
#a list of lists where each document is a string broken into a list of words
cleaned_corpus_GOT = []
for document in cleaner_corpus_GOT:
    cleaned_corpus_GOT.append([word for word in document if word not in bad_high_words_GOT])

# %%
#pickle.dump(cleaned_corpus_GOT, open("cleaned_corpus_GOT_monday.pkl", "wb" ) )

# %%
extra_stop_words = ['ign', 'diggory', 'cedric', 'timon', 'pumba', 'arnold', 'gotzmilk', 'episode', 'season', 'character', 'show', 
                    'amp', 'xb', 'de', 'et', 'le', 'http', 'la', 'com', 'il', 'de', 'gt', 'se', 'gt', 'qui', 'lt', 'xb', 'amp',
                   'one', 'would', 'could', 'gif', "youl'", 'may', 'get', 'instagram', 'aa','aaa','aaaaaaand','aaaaand','aaaand','aaand',
 'aabns',
 'aabxbmaea',
 'aafdadceaf',
 'aarambha',
 'aaron',
 'aarya',
 'ab', 'abc', 'er', 'nk', 'ww' ]

# %%
further_cleaned_corpus_GOT = []
for document in cleaned_corpus_GOT:
    further_cleaned_corpus_GOT.append([word for word in document if word not in extra_stop_words])

# %%
#pickle.dump(further_cleaned_corpus_GOT, open("further_cleaned_corpus_GOT_monday.pkl", "wb" ) )

# %%
final_GOT = []

for item in further_cleaned_corpus_GOT:
    item = ' '.join(item)
    final_GOT.append(item)

# %%
#pickle.dump(final_GOT, open("final_got_monday.pkl", "wb" ))
