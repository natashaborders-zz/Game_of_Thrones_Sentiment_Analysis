# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.datasets import fetch_20newsgroups
import numpy as np
import pickle
import pandas as pd
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity

# %%
got = pickle.load( open( "./Data/final_got_monday.pkl", "rb" ) )
asoiaf_reddit = pickle.load( open( "./Data/final_asoiaf_monday.pkl", "rb" ) )
freefolk_reddit = pickle.load( open( "./Data/final_freefolk_monday.pkl", "rb" ) )

# %%
got_reddit = pickle.load( open( "./Data/got_reddit_ready_vector_monday.pkl", "rb" ) )
asoiaf_reddit = pickle.load( open( "./Data/soiaf_reddit_ready_vector_monday.pkl", "rb" ) )
freefolk_reddit = pickle.load( open( "./Data/freefolk_reddit_ready_vector_monday.pkl", "rb" ) )

# %%
got_reddit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153179 entries, 0 to 158663
# Data columns (total 7 columns):
# Publish Date          153179 non-null object
# body                  153179 non-null object
# sentiment             153179 non-null object
# sentiment_compound    153179 non-null object
# sentiment_sum         153179 non-null object
# sentiment_mean        153179 non-null object
# clean                 153179 non-null object
# dtypes: object(7)
# memory usage: 9.3+ MB

# %%
len(got)
# Out:
# 153179

# %%
forum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3078 entries, 0 to 3077
# Data columns (total 2 columns):
# Date_Created    3078 non-null object
# clean           3078 non-null object
# dtypes: object(2)
# memory usage: 72.1+ KB

# %%
len(forum)
# Out:
# 3078

# %%
forum = forum.rename(columns = {'Date_Created': 'Publish Date'})

# %%
forum['Publish Date'] = pd.to_datetime(forum['Publish Date'])

# %%
forum
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3078 entries, 0 to 3077
# Data columns (total 2 columns):
# Publish Date    3078 non-null object
# clean           3078 non-null object
# dtypes: object(2)
# memory usage: 72.1+ KB

# %%
freefolk_reddit['Publish Date'] = pd.to_datetime(freefolk_reddit['Publish Date'])
got_reddit['Publish Date'] = pd.to_datetime(got_reddit['Publish Date'])
asoiaf_reddit['Publish Date'] = pd.to_datetime(asoiaf_reddit['Publish Date'])

# %%
freefolk_reddit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175822 entries, 0 to 189773
# Data columns (total 7 columns):
# Publish Date          175822 non-null datetime64[ns]
# body                  175822 non-null object
# sentiment             175822 non-null object
# sentiment_compound    175822 non-null object
# sentiment_sum         175822 non-null object
# sentiment_mean        175822 non-null object
# clean                 175822 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 10.7+ MB

# %%
asoiaf_reddit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28280 entries, 0 to 28806
# Data columns (total 7 columns):
# Publish Date          28280 non-null datetime64[ns]
# body                  28280 non-null object
# sentiment             28280 non-null object
# sentiment_compound    28280 non-null object
# sentiment_sum         28280 non-null object
# sentiment_mean        28280 non-null object
# clean                 28280 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 1.7+ MB

# %%
forum = pickle.load( open( "./Data/westeros_date.pkl", "rb" ) )

# %%
forum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3078 entries, 0 to 3077
# Data columns (total 2 columns):
# Date_Created    3078 non-null object
# clean           3078 non-null object
# dtypes: object(2)
# memory usage: 72.1+ KB

# %%
forum['Publish Date'] = forum['Date_Created']

# %%
def transformation(df):
    for i, j in df.iterrows(): 
            df['Publish Date'][i] = df['Publish Date'][i][:-5]
            df['Publish Date'][i] = df['Publish Date'][i][:10] + ' ' + df['Publish Date'][i][11:]

# %%
transformation(forum)

# %%
forum['Date'] = pd.to_datetime(forum['Publish Date'])

# %%
forum['Publish Date'] = forum['Date']

# %%
forum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3078 entries, 0 to 3077
# Data columns (total 4 columns):
# Date_Created    3078 non-null object
# clean           3078 non-null object
# Publish Date    3078 non-null datetime64[ns]
# Date            3078 non-null datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 200.2+ KB

# %%
database_list = [forum, got_reddit, freefolk_reddit, asoiaf_reddit]

# %%
total_giant_dataframe = pd.concat(database_list, ignore_index = True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
total_giant_dataframe
# Out:
#                       Date              Date_Created        Publish Date  \
# 0      2019-04-15 14:50:12  2019-04-15T14:50:12+0000 2019-04-15 14:50:12
# 1      2019-04-15 01:41:17  2019-04-15T01:41:17+0000 2019-04-15 01:41:17
# 2      2019-04-15 01:45:02  2019-04-15T01:45:02+0000 2019-04-15 01:45:02
# 3      2019-04-15 01:46:33  2019-04-15T01:46:33+0000 2019-04-15 01:46:33
# 4      2019-04-15 01:58:53  2019-04-15T01:58:53+0000 2019-04-15 01:58:53
# 5      2019-04-15 02:00:13  2019-04-15T02:00:13+0000 2019-04-15 02:00:13
# 6      2019-04-15 02:01:59  2019-04-15T02:01:59+0000 2019-04-15 02:01:59
# 7      2019-04-15 02:04:36  2019-04-15T02:04:36+0000 2019-04-15 02:04:36
# 8      2019-04-15 02:05:51  2019-04-15T02:05:51+0000 2019-04-15 02:05:51
# 9      2019-04-15 02:08:27  2019-04-15T02:08:27+0000 2019-04-15 02:08:27
# 10     2019-04-15 02:08:35  2019-04-15T02:08:35+0000 2019-04-15 02:08:35
# 11     2019-04-15 02:08:37  2019-04-15T02:08:37+0000 2019-04-15 02:08:37
# 12     2019-04-15 02:09:01  2019-04-15T02:09:01+0000 2019-04-15 02:09:01
# 13     2019-04-15 02:10:06  2019-04-15T02:10:06+0000 2019-04-15 02:10:06
# 14     2019-04-15 02:10:27  2019-04-15T02:10:27+0000 2019-04-15 02:10:27
# 15     2019-04-15 02:11:49  2019-04-15T02:11:49+0000 2019-04-15 02:11:49
# 16     2019-04-15 02:12:00  2019-04-15T02:12:00+0000 2019-04-15 02:12:00
# 17     2019-04-15 02:12:26  2019-04-15T02:12:26+0000 2019-04-15 02:12:26
# 18     2019-04-15 02:13:12  2019-04-15T02:13:12+0000 2019-04-15 02:13:12
# 19     2019-04-15 02:14:46  2019-04-15T02:14:46+0000 2019-04-15 02:14:46
# 20     2019-04-15 02:17:35  2019-04-15T02:17:35+0000 2019-04-15 02:17:35
# 21     2019-04-14 20:05:17  2019-04-14T20:05:17+0000 2019-04-14 20:05:17
# 22     2019-04-15 02:17:45  2019-04-15T02:17:45+0000 2019-04-15 02:17:45
# 23     2019-04-15 02:18:07  2019-04-15T02:18:07+0000 2019-04-15 02:18:07
# 24     2019-04-15 02:18:35  2019-04-15T02:18:35+0000 2019-04-15 02:18:35
# 25     2019-04-15 02:19:50  2019-04-15T02:19:50+0000 2019-04-15 02:19:50
# 26     2019-04-15 02:20:18  2019-04-15T02:20:18+0000 2019-04-15 02:20:18
# 27     2019-04-15 02:21:20  2019-04-15T02:21:20+0000 2019-04-15 02:21:20
# 28     2019-04-15 02:21:32  2019-04-15T02:21:32+0000 2019-04-15 02:21:32
# 29     2019-04-15 02:22:06  2019-04-15T02:22:06+0000 2019-04-15 02:22:06
# ...                    ...                       ...                 ...
# 360329                 NaT                       NaN 2019-04-25 05:01:09
# 360330                 NaT                       NaN 2019-04-25 05:27:27
# 360331                 NaT                       NaN 2019-04-25 05:35:21
# 360332                 NaT                       NaN 2019-04-25 05:35:34
# 360333                 NaT                       NaN 2019-04-25 05:36:19
# 360334                 NaT                       NaN 2019-04-25 05:45:18
# 360335                 NaT                       NaN 2019-04-25 05:56:14
# 360336                 NaT                       NaN 2019-04-25 06:00:26
# 360337                 NaT                       NaN 2019-04-25 06:08:33
# 360338                 NaT                       NaN 2019-04-25 06:10:26
# 360339                 NaT                       NaN 2019-04-25 06:11:06
# 360340                 NaT                       NaN 2019-04-25 06:11:30
# 360341                 NaT                       NaN 2019-04-25 06:12:28
# 360342                 NaT                       NaN 2019-04-25 06:15:07
# 360343                 NaT                       NaN 2019-04-25 06:25:26
# 360344                 NaT                       NaN 2019-04-25 06:34:08
# 360345                 NaT                       NaN 2019-04-25 06:44:24
# 360346                 NaT                       NaN 2019-04-25 06:47:19
# 360347                 NaT                       NaN 2019-04-25 06:47:22
# 360348                 NaT                       NaN 2019-04-25 06:49:09
# 360349                 NaT                       NaN 2019-04-25 06:49:29
# 360350                 NaT                       NaN 2019-04-25 06:51:12
# 360351                 NaT                       NaN 2019-04-25 06:51:26
# 360352                 NaT                       NaN 2019-04-25 06:55:49
# 360353                 NaT                       NaN 2019-04-25 06:56:42
# 360354                 NaT                       NaN 2019-04-25 07:29:19
# 360355                 NaT                       NaN 2019-04-25 07:30:21
# 360356                 NaT                       NaN 2019-04-25 07:44:18
# 360357                 NaT                       NaN 2019-04-25 07:49:33
# 360358                 NaT                       NaN 2019-04-25 07:52:06
#
#                                                      body  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 360329                     Read in the house of the worm.
# 360330  This is a very interesting take on Nissa Nissa...
# 360331  Lightbeinger and the myth Behind it is not a t...
# 360332  How does the sword /become/ lightbringer thoug...
# 360333  I can't remember if it was in the show or the ...
# 360334  i think i missed it. can some please explain h...
# 360335  Bran could also be looking at Jamie as a good ...
# 360336  Except I dont think the Night King is going to...
# 360337                              I really hope he does
# 360338  He'll probably be a hero in a way that the leg...
# 360339                                   Wow I love that.
# 360340  After re-watch, I think Bran pretty much tells...
# 360341  I like this theory. If Jaime were to kill wigh...
# 360342  What if brienne is mortally wounded and to put...
# 360343  I'm calling it: Beric Dondarrion is going down...
# 360344  I’m so glad I’m not the only one who came to t...
# 360345  Also, Jaime saying a thousand times how he can...
# 360346  While I think that your theories are very inte...
# 360347  You guys are so good at coming up with these t...
# 360348  While I really like this idea, I feel like we ...
# 360349  I already [**said this**](https://www.reddit.c...
# 360350  And what better way to complete his arc than b...
# 360351  I’ve always thought the same about that earlie...
# 360352  I just don't know that the show has done a goo...
# 360353  If Jaime has to kill wight-Brienne I'm gonna l...
# 360354  King slayer is the biggest clue to me Jaime Ta...
# 360355  I don't know if your theory is a good one, but...
# 360356  Jaime doesn't love Brienne that way, so I don'...
# 360357  the prophecy is going to glitch out. Arya will...
# 360358  Jaime certainly gets the people's vote. Nikola...
#
#                                                     clean  \
# 0       book discussion show go want discus episode re...
# 1       book discussion show go want discus episode re...
# 2                              ok love dragon scene ghost
# 3       far im liking episode far especially little bi...
# 4        fun scene holy shit jon mustve hanging dear life
# 5       jon seriously went rode dragon everybody ride ...
# 6       wow much happening say much happier jon arya r...
# 7              episode enjoyable totally mostly set shame
# 8       laptop broke right group rode winterfell yard ...
# 9       seems pointing idea play simply night king kil...
# 10                   think whole r l j badly handled show
# 11             anyone else notice call back first episode
# 12      felt soooo bad sam right question asked jon en...
# 13      message mean creepy siimbol nobody know meanin...
# 14                                         anti climactic
# 15      enjoyed fact randylls dickons death impact sto...
# 16      well think simply meant remind u others arent ...
# 17      find hard believe sam wouldnt know dad brother...
# 18      episode title missed watched opening credit st...
# 19      feel much callback music lineup complimenting ...
# 20             loved ending bran waiting old friend great
# 21                                  harry actually faegon
# 22                                  harry actually faegon
# 23      mostly enjoyable loved stark reunion liked mor...
# 24                         someone ship could called help
# 25      always disliked winter culture architecture ci...
# 26                             criticized way back season
# 27      yep little boy stand arya smirk memory also pl...
# 28      daenerys really threatened sansa front jon sno...
# 29      else thought sam made noise crypt brought bran...
# ...                                                   ...
# 360329                                    read house worm
# 360330  interesting take nissa nissa like jaime favori...
# 360331  lightbeinger myth behind thing show prophecy s...
# 360332               sword become though one seem explain
# 360333  remember show book think line someday nobody r...
# 360334                               think please explain
# 360335  bran could also looking jamie good sacrifice c...
# 360336  except dont think night king going die believe...
# 360337                                        really hope
# 360338  probably hero way spoken subvert moniker somet...
# 360339                                           wow love
# 360340                       watch think bran pretty much
# 360341  like theory jaime kill wight brienne either wi...
# 360342  mortally wounded put misery wight turning jami...
# 360343  calling beric dondarrion going jaime use flami...
# 360344  glad one came conclusion office death pool bon...
# 360345  also jaime saying thousand time fight hero pre...
# 360346  think interesting mind happening thing though ...
# 360347            good coming winterfell built magic wall
# 360348  really like idea feel like would another nissa...
# 360349              already said r everything king slayer
# 360350  better way complete arc completely perception ...
# 360351  always thought figured would cersei definitely...
# 360352  know show done good enough job legend audience...
# 360353  jaime kill wight brienne lose mind hope wrong ...
# 360354  king slayer biggest clue jaime targaryen daddy...
# 360355                          know theory good one wish
# 360356      jaime love brienne way agree neat idea though
# 360357  prophecy going arya kill cersei jamie face tri...
# 360358  jaime certainly people vote nikolaj well hard ...
#
#                                                 sentiment  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 360329  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 360330  [{'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'com...
# 360331  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 360332  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 360333  [{'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'com...
# 360334  [{'neg': 0.524, 'neu': 0.476, 'pos': 0.0, 'com...
# 360335  [{'neg': 0.149, 'neu': 0.686, 'pos': 0.166, 'c...
# 360336  [{'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'com...
# 360337  [{'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'com...
# 360338  [{'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'com...
# 360339  [{'neg': 0.0, 'neu': 0.111, 'pos': 0.889, 'com...
# 360340  [{'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'com...
# 360341  [{'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'com...
# 360342  [{'neg': 0.045, 'neu': 0.955, 'pos': 0.0, 'com...
# 360343  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 360344  [{'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'com...
# 360345  [{'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'com...
# 360346  [{'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compoun...
# 360347  [{'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'com...
# 360348  [{'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'com...
# 360349  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 360350  [{'neg': 0.125, 'neu': 0.793, 'pos': 0.082, 'c...
# 360351  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 360352  [{'neg': 0.137, 'neu': 0.776, 'pos': 0.087, 'c...
# 360353  [{'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'com...
# 360354  [{'neg': 0.162, 'neu': 0.838, 'pos': 0.0, 'com...
# 360355  [{'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'com...
# 360356  [{'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'com...
# 360357  [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 360358  [{'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'com...
#
#                                        sentiment_compound sentiment_mean  \
# 0                                                     NaN            NaN
# 1                                                     NaN            NaN
# 2                                                     NaN            NaN
# 3                                                     NaN            NaN
# 4                                                     NaN            NaN
# 5                                                     NaN            NaN
# 6                                                     NaN            NaN
# 7                                                     NaN            NaN
# 8                                                     NaN            NaN
# 9                                                     NaN            NaN
# 10                                                    NaN            NaN
# 11                                                    NaN            NaN
# 12                                                    NaN            NaN
# 13                                                    NaN            NaN
# 14                                                    NaN            NaN
# 15                                                    NaN            NaN
# 16                                                    NaN            NaN
# 17                                                    NaN            NaN
# 18                                                    NaN            NaN
# 19                                                    NaN            NaN
# 20                                                    NaN            NaN
# 21                                                    NaN            NaN
# 22                                                    NaN            NaN
# 23                                                    NaN            NaN
# 24                                                    NaN            NaN
# 25                                                    NaN            NaN
# 26                                                    NaN            NaN
# 27                                                    NaN            NaN
# 28                                                    NaN            NaN
# 29                                                    NaN            NaN
# ...                                                   ...            ...
# 360329                                              [0.0]
# 360330                   [0.6697, 0.4588, 0.6369, 0.7783]
# 360331                                 [0.0, 0.0, -0.296]
# 360332                                         [0.0, 0.0]
# 360333                                           [0.8807]
# 360334                                   [-0.296, 0.3182]
# 360335                                           [0.0772]
# 360336                    [-0.5994, 0.25, 0.3818, 0.7422]
# 360337                                           [0.4927]
# 360338                                    [0.802, 0.2732]
# 360339                                           [0.8402]
# 360340                                           [0.4939]
# 360341                                  [0.3612, -0.6908]
# 360342                                          [-0.1027]
# 360343                                         [0.0, 0.0]
# 360344                         [0.5095, -0.7096, -0.2023]
# 360345                                           [0.8395]
# 360346  [0.4576, -0.8316, -0.6705, -0.25, 0.4588, -0.5...
# 360347                                      [0.5777, 0.0]
# 360348                              [0.6794, 0.0, 0.6997]
# 360349                                              [0.0]
# 360350                          [-0.3612, -0.3182, -0.25]
# 360351                                 [0.0, 0.8873, 0.0]
# 360352                                 [-0.4019, -0.5423]
# 360353                                  [-0.8126, 0.4019]
# 360354                                          [-0.4404]
# 360355                                           [0.6705]
# 360356                                  [-0.6962, 0.4588]
# 360357                              [0.0, -0.6908, -0.34]
# 360358                                     [0.34, 0.4077]
#
#        sentiment_sum
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ...              ...
# 360329             0
# 360330        2.5437
# 360331        -0.296
# 360332             0
# 360333        0.8807
# 360334        0.0222
# 360335        0.0772
# 360336        0.7746
# 360337        0.4927
# 360338        1.0752
# 360339        0.8402
# 360340        0.4939
# 360341       -0.3296
# 360342       -0.1027
# 360343             0
# 360344       -0.4024
# 360345        0.8395
# 360346       -1.3624
# 360347        0.5777
# 360348        1.3791
# 360349             0
# 360350       -0.9294
# 360351        0.8873
# 360352       -0.9442
# 360353       -0.4107
# 360354       -0.4404
# 360355        0.6705
# 360356       -0.2374
# 360357       -1.0308
# 360358        0.7477
#
# [360359 rows x 9 columns]

# %%
total_giant_dataframe['Publish Date'] = pd.to_datetime(total_giant_dataframe['Publish Date'])

# %%
total_giant_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360359 entries, 0 to 360358
# Data columns (total 9 columns):
# Date                  3078 non-null datetime64[ns]
# Date_Created          3078 non-null object
# Publish Date          360359 non-null datetime64[ns]
# body                  357281 non-null object
# clean                 360359 non-null object
# sentiment             357281 non-null object
# sentiment_compound    357281 non-null object
# sentiment_mean        357281 non-null object
# sentiment_sum         357281 non-null object
# dtypes: datetime64[ns](2), object(7)
# memory usage: 24.7+ MB

# %%
total_giant_dataframe = total_giant_dataframe[['Publish Date', 'clean']]

# %%
total_giant_dataframe.to_csv('total_giant_dataframe.csv', index = False)

# %%
total_giant_dataframe = total_giant_dataframe.set_index('Publish Date')

# %%
total_giant_dataframe = total_giant_dataframe.dropna()

# %%
total_giant_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360359 entries, 0 to 360358
# Data columns (total 2 columns):
# Publish Date    360359 non-null datetime64[ns]
# clean           360359 non-null object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 8.2+ MB

# %%
total_giant_dataframe.to_csv('total_giant_dataframe.csv', index = False)

# %%
total_giant_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360359 entries, 0 to 360358
# Data columns (total 2 columns):
# Publish Date    360359 non-null datetime64[ns]
# clean           360359 non-null object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 8.2+ MB
