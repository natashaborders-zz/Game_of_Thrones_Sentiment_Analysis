# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import pickle

# %%
freefolk = pickle.load( open( "./Data/freefolk_reddit_ready_vector.pkl", "rb" ) )

# %%
count_dict_freefolk = {}

for doc in freefolk['clean']:
    for word in doc.split():
        if word in count_dict_freefolk.keys():
            count_dict_freefolk[word] +=1
        else:
            count_dict_freefolk[word] = 1

# %%
low_value = 20
bad_words_freefolk = [key for key in count_dict_freefolk.keys() if count_dict_freefolk[key] < low_value]

# %%
high_value = 20000
bad_high_words_freefolk = [key for key in count_dict_freefolk.keys() if count_dict_freefolk[key] > high_value]

# %%
corpus = [doc.split() for doc in freefolk['clean']]

# %%
cleaner_corpus_freefolk = []
for document in corpus:
    cleaner_corpus_freefolk.append([word for word in document if word not in bad_words_freefolk])

# %%
cleaned_corpus_freefolk = []
for document in cleaner_corpus_freefolk:
    cleaned_corpus_freefolk.append([word for word in document if word not in bad_high_words_freefolk])

# %%
pickle.dump(cleaned_corpus_freefolk, open("cleaned_corpus_freefolk.pkl", "wb" ) )
# Out:
# [['open',
#   'bidding',
#   'open',
#   'call',
#   'anyone',
#   'provide',
#   'season',
#   'name',
#   'price',
#   'frikidoctor',
#   'confirm',
#   'info',
#   'via',
#   'pm',
#   'please',
#   'provide',
#   'paypal',
#   'bitcoin',
#   'contact',
#   'info',
#   'wire',
#   'transfer',
#   'pm',
#   'info',
#   'regarding',
#   'respond',
#   'openly',
#   'thread',
#   'regarding',
#   'serious',
#   'inquiry'],
#  ['day', 'fourth', 'quote', 'day'],
#  ['south', 'park', 'know'],
#  ['pork', 'sausage'],
#  ['sunday',
#   'time',
#   'term',
#   'script',
#   'none',
#   'starks',
#   'happy',
#   'see',
#   'daenerys',
#   'fellow',
#   'targaryen',
#   'killed',
#   'uncle',
#   'haven’t',
#   'forgotten',
#   'emilia',
#   'clarke',
#   'also',
#   'say',
#   'starks',
#   'like',
#   'dany',
#   'ask',
#   'clarke',
#   'set',
#   'scene',
#   'sits',
#   'end',
#   'day',
#   '”',
#   'say',
#   'full',
#   'length',
#   'bone',
#   'white',
#   'fur',
#   'coat',
#   '“but',
#   'don’t',
#   'like',
#   'definitely',
#   'whole',
#   'winterfell',
#   'daenerys',
#   'ep',
#   'interesting'],
#  [],
#  ['dumb', 'cunt'],
#  ['help', 'u', 'hbo', 'spain', 'hope'],
#  ['could',
#   'guess',
#   'tycho',
#   'nestoris',
#   'employee',
#   'iron',
#   'bank',
#   'st',
#   'officialy',
#   'survived',
#   'long',
#   'night',
#   'actor',
#   'admitted',
#   'august'],
#  ['supposed', 'dragonpit', 'according', 'friki'],
#  ['reaction', 'past', 'hour', 'reading', 'frikidoctors', 'bad', 'news'],
#  ['love', 'little', 'echo', 'chamber'],
#  ['mini', 'tease', 'aired', 'second', 'new', 'scene', 'speak', 'jon'],
#  ['new', 'promo', 'new', 'footage'],
#  ['mini',
#   'teaser',
#   'aired',
#   'hbo',
#   'second',
#   'new',
#   'snippet',
#   'jon',
#   'voiceover'],
#  ['new', 'footage'],
#  ['mother',
#   'dragon',
#   'must',
#   'tough',
#   'gotta',
#   'gallon',
#   'milk',
#   'feed',
#   'beast'],
#  ['fuck'],
#  ['bobby', 'b', 'deserved', 'better'],
#  ['lannister'],
#  ['rip', 'frikidoctor', 'lot', 'youtube', 'channel', 'wrong'],
#  ['new',
#   'promo',
#   'titled',
#   'sneak',
#   'peak',
#   '“die”',
#   'assuming',
#   'mean',
#   'th'],
#  ['new', 'hd', 'footage'],
#  ['here', 'really', 'happened', 'hbo', 'frikidoctor'],
#  ['new', 'promo'],
#  ['friki', 'leak', 'check', 'arrangement'],
#  ['kaysen',
#   'melisandre',
#   'sub',
#   'appreciate',
#   'true',
#   'prediction',
#   'lady',
#   'freefolk',
#   'dark',
#   'full'],
#  ['bit', 'clearer', 'footage', 'new', 'promo'],
#  ['best', 'quality', 'seen', 'http', 'twitter', 'com', 'status'],
#  ['jon', 'daenerys', 'white', 'walker', 'attack'],
#  ['day', 'upcoming', 'quote'],
#  ['pounce', 'promised'],
#  ['damn', 'jon', 'rough', 'night'],
#  ['love', 'battle', 'ready', 'jon'],
#  ['longclaw', 'disintegrated'],
#  ['binge',
#   'like',
#   'addict',
#   'starting',
#   'full',
#   'season',
#   'binge',
#   'big',
#   'day',
#   'anyone',
#   'else',
#   'starting',
#   'today',
#   'viewing',
#   'party',
#   'rd',
#   'full',
#   'watch',
#   'since',
#   'january'],
#  ['peter', 'dinklage', 'doppelganger', 'found'],
#  ['hbo', 'trailer', 'hopefully', 'better', 'video'],
#  ['still',
#   'mel',
#   'shot',
#   'fine',
#   'new',
#   'content',
#   'second',
#   'heaven',
#   'angry',
#   'bloody',
#   'jon',
#   'quick',
#   'cersei',
#   'shot',
#   'scene',
#   'jon',
#   'daenerys',
#   'back',
#   'seven',
#   'hell'],
#  ['doubted',
#   'friki',
#   'dany',
#   'sansa',
#   'seated',
#   'either',
#   'side',
#   'jon',
#   'definitely',
#   'behind',
#   'tyrion'],
#  ['recorded', 'p', 'tv', 'hope', 'it’s', 'better', 'guy'],
#  ['jaime', 'cast', 'chuck', 'norris'],
#  ['reference', 'hardhome', 'winterfell', 'afraid'],
#  ['happened', 'pause', 'scene', 'look', 'like', 'painting', 'museum'],
#  ['hardhome', 'reference', 'confirmed', 'battle', 'winterfell', 'f'],
#  ['dany',
#   'jon',
#   'dragon',
#   'flying',
#   'scene',
#   'sansa',
#   'witnessing',
#   'arrival',
#   'winterfell'],
#  ['arya', 'spinning', 'double', 'dragon', 'glass', 'bladed', 'spear'],
#  ['shes', 'dragonstone'],
#  ['undead', 'viserion'],
#  ['tormund', 'legend'],
#  ['personal', 'thought', 'frikidoctor', 'bending', 'knee'],
#  ['never', 'forget', 'held', 'gate'],
#  ['little', 'freaky', 'sub', 'still', 'love', 'tho'],
#  ['beric', 'wf', 'battle', 'ed', 'tormund'],
#  ['beric', 'wf', 'battle', 'ed', 'tormund'],
#  ['shireen', 'baratheon', 'theme', 'song'],
#  ['melisandre', 'first', 'picture', 'barely', 'see', 'eye', 'mouth'],
#  ['dragonglass', 'unsullied', 'shield'],
#  ['raven',
#   'gt',
#   'internet',
#   'raven',
#   'westeros',
#   'it’s',
#   'quite',
#   'fast',
#   'firm',
#   'everyone',
#   'get',
#   'news',
#   'knowledge',
#   'yes',
#   'hack',
#   'killing',
#   'raven',
#   'cannot',
#   'stop',
#   'totally',
#   'wonder',
#   'play',
#   'game',
#   'different',
#   'city',
#   'arya',
#   'play',
#   'game',
#   'face',
#   'winterfell',
#   'man',
#   'bravo',
#   'would',
#   'fun'],
#  ['official', 'lord', 'varys', 'invented', 'double', 'suit', 'time'],
#  ['got', 'bellagio', 'fountain', 'display', 'ending'],
#  ['bran',
#   'nk',
#   'theory',
#   'still',
#   'holding',
#   'moved',
#   'passed',
#   'back',
#   'burner'],
#  ['can’t', 'friend'],
#  ['question', 'sneak', 'peak', 'gonna', 'officially', 'posted', 'sure', 'yet'],
#  ['second', 'teaser'],
#  ['arya', 'jon', 'reunite', 'weirwood'],
#  ['second', 'teaser'],
#  ['waiting', 'ghost'],
#  ['omg', 'amp', 'xb', 'http', 'redd', 'jpg'],
#  ['jon', 'lighting', 'candle', 'lyannas', 'statue'],
#  ['seriously', 'sense', 'fun', 'stale', 'subreddit'],
#  ['dishonorable', 'especially', 'considering', 'recent', 'news'],
#  ['arya',
#   'one',
#   'comfort',
#   'jon',
#   'based',
#   'second',
#   'teaser',
#   'http',
#   'www',
#   'reddit',
#   'com',
#   'r',
#   'freefolk',
#   'comment',
#   'second',
#   'teaser',
#   'tonight',
#   'seems',
#   'like',
#   'arya',
#   'twice',
#   'comfort',
#   'jon',
#   'sam',
#   'drop',
#   'bomb',
#   'crypt',
#   'near',
#   'lyanna',
#   'statue',
#   'weirwood',
#   'tree',
#   'seems',
#   'little',
#   'sister',
#   'still',
#   'one',
#   'best',
#   'understands',
#   'big',
#   'brother'],
#  ['anyone',
#   'nd',
#   'teaser',
#   'everyone',
#   'seem',
#   'interested',
#   'visuals',
#   'think',
#   'got',
#   'something',
#   'new',
#   'dialogue',
#   'could',
#   'understand',
#   'extent'],
#  ['day', 'quote', 'day', 'another', 'one', 'season'],
#  ['it’s',
#   'extremely',
#   'odd',
#   'nothing',
#   'uploaded',
#   'youtube',
#   'well',
#   'something',
#   'official'],
#  ['day', 'quote', 'day', 'another', 'one', 'season'],
#  ['edit', 'thanks', 'gold', 'king', 'stranger'],
#  ['p', 'second', 'teaser', 'hope', 'help'],
#  ['jon',
#   'still',
#   'wearing',
#   'stark',
#   'armour',
#   'stage',
#   'crypt',
#   'rip',
#   'dany',
#   'go',
#   'see',
#   'still',
#   'look',
#   'downwards'],
#  ['jaime',
#   'learned',
#   'fuck',
#   'loyalty',
#   'second',
#   'trailer',
#   'one',
#   'say',
#   'beyond',
#   'loyalty',
#   'survival',
#   'brienne',
#   'gotten',
#   'dumbest',
#   'lannister',
#   'loud',
#   'clear'],
#  ['please', 'help', 'i’m', 'dead'],
#  ['jon', 'telling', 'dany', 'need', 'leave', 'deal', 'cersei'],
#  ['something',
#   'bugging',
#   'hardhome',
#   'ok',
#   'know',
#   'jon',
#   'tormund',
#   'take',
#   'stannis',
#   'fleet',
#   'north',
#   'eastwatch',
#   'get',
#   'freefolk',
#   'hardhomme',
#   'bugging',
#   'return',
#   'back',
#   'eastwatch',
#   'instead',
#   'ship',
#   'dropped',
#   'north',
#   'wall',
#   'leading',
#   'scene',
#   'jon',
#   'lead',
#   'freefolk',
#   'gate',
#   'cb',
#   'mean',
#   'ship',
#   'already',
#   'headed',
#   'back',
#   'eastwatch',
#   'make',
#   'sense'],
#  ['rhaella',
#   'lyanna',
#   'foreshadow',
#   'http',
#   'radikal',
#   'ru',
#   'jpg',
#   'jon',
#   'sad',
#   'emotional',
#   'look',
#   'better',
#   'didn’t',
#   'leave',
#   'turned',
#   'exactly',
#   'side',
#   'probably',
#   'went',
#   'comfort',
#   'it’s',
#   'really',
#   'great',
#   'foreshadow',
#   'rhaegar',
#   'left',
#   'lyanna',
#   'tower',
#   'joy',
#   'traveled',
#   'war',
#   'pregnant',
#   'moment',
#   'heart',
#   'stop',
#   'breathing',
#   'it’s',
#   'really',
#   'sad',
#   'tragic',
#   'can’t',
#   'imagine',
#   'feeling',
#   'lot',
#   'foreshadow',
#   'dany',
#   'born',
#   'mother',
#   'dead',
#   'lyanna',
#   'great',
#   'great',
#   'foreshadow',
#   'dany',
#   'greatest',
#   'win',
#   'death',
#   'give',
#   'birth',
#   'survive',
#   'jon',
#   'dany',
#   'change',
#   'story',
#   'cannot',
#   'wait'],
#  ['could',
#   'frikidoctor',
#   'danger',
#   'effort',
#   'fuck',
#   'hbo',
#   'taken',
#   'silence',
#   'think',
#   'crazy',
#   'could',
#   'hire',
#   'thug',
#   'hurt',
#   'especially',
#   'sketchy',
#   'country',
#   'like',
#   'spain'],
#  ['jon', 'fire', 'promo', 'beautiful', 'shot', 'jon', 'ned'],
#  ['always', 'concept', 'art', 'amp', 'simon'],
#  ['go',
#   'beyond',
#   'loyalty',
#   'survival',
#   'first',
#   'part',
#   'loose',
#   'transcription',
#   'brienne',
#   'word',
#   'dragonpit',
#   'second',
#   'part',
#   'jon',
#   'opening',
#   'line',
#   'wildlings',
#   'hardhome',
#   'thought',
#   'nice',
#   'touch'],
#  ['family', 'brooding', 'intensifies'],
#  ['sneak', 'peak', 'p', 'together'],
#  ['daenaerys', 'celebrates', 'ride', 'large', 'cock'],
#  ['daenaerys', 'celebrates', 'ride', 'large', 'cock'],
#  ['compilation', 'game', 'throne', 'audition'],
#  ['arya', 'jon'],
#  ['new', 'teaser', 'non', 'phone', 'recording'],
#  ['sister', 'watching', 'red', 'wedding', 'first', 'time'],
#  ['think',
#   'back',
#   'started',
#   'fooking',
#   'sure',
#   'se',
#   'jon',
#   'mother',
#   'bastard'],
#  ['imagery',
#   'daenerys',
#   'sansa',
#   'together',
#   'make',
#   'look',
#   'like',
#   'complete',
#   'opposite',
#   'daenerys',
#   'white',
#   'red',
#   'amp',
#   'grey',
#   'sansa',
#   'black',
#   'hint',
#   'grey',
#   'odd',
#   'since',
#   'one',
#   'main',
#   'color',
#   'house',
#   'targaryen',
#   'black',
#   'house',
#   'stark',
#   'one',
#   'white'],
#  ['wonder',
#   'friki',
#   'ever',
#   'going',
#   'look',
#   'back',
#   'say',
#   'man',
#   'let',
#   'lot',
#   'people',
#   'made',
#   'difference',
#   'looking',
#   'back',
#   'leak',
#   'actually',
#   'helped',
#   'whole',
#   'fandom',
#   'expand',
#   'buzz',
#   'grow',
#   'right',
#   'much',
#   'le',
#   'buzz',
#   'finale',
#   'season',
#   'still',
#   'disprove',
#   'game',
#   'time',
#   'casual',
#   'people',
#   'new',
#   'season',
#   'still',
#   'even',
#   'know',
#   'premiere',
#   'date',
#   'go',
#   'figure'],
#  ['wonder',
#   'friki',
#   'ever',
#   'going',
#   'look',
#   'back',
#   'say',
#   'man',
#   'let',
#   'lot',
#   'people',
#   'considering',
#   'difference',
#   'looking',
#   'back',
#   'leak',
#   'actually',
#   'helped',
#   'whole',
#   'fandom',
#   'expand',
#   'buzz',
#   'crazy',
#   'grow',
#   'right',
#   'much',
#   'le',
#   'fewer',
#   'buzz',
#   'finale',
#   'season',
#   'certain',
#   'demographic',
#   'unheard',
#   'season',
#   'still',
#   'disprove',
#   'game',
#   'day',
#   'like',
#   'super',
#   'bowl',
#   'world',
#   'cup',
#   'still',
#   'tune',
#   'en',
#   'mass',
#   'find',
#   'many',
#   'people',
#   'going',
#   'dvr',
#   'record',
#   'shit',
#   'summer',
#   'well',
#   'buzz',
#   'frankly',
#   'casual',
#   'people',
#   'knew',
#   'season',
#   'still',
#   'even',
#   'know',
#   'premiere',
#   'date',
#   'go',
#   'figure',
#   'season',
#   'bugged',
#   'hell',
#   'shit',
#   'hype',
#   'u',
#   'fanboys',
#   'gave'],
#  ['th', 'article'],
#  ['jon',
#   'immediately',
#   'tell',
#   'daenerys',
#   'involuntary',
#   'incest',
#   'jon',
#   'definitely',
#   'concerned',
#   'image',
#   'got',
#   'see',
#   'far',
#   'little',
#   'usual',
#   'seems',
#   'find',
#   'real',
#   'name',
#   'pretty',
#   'soon',
#   'least',
#   'battle',
#   'winterfell',
#   'daenerys',
#   'look',
#   'picture',
#   'crypt',
#   'room',
#   'front',
#   'fire',
#   'place',
#   'look',
#   'unhappy',
#   'jon',
#   'told',
#   'daenerys',
#   'truth',
#   'behaving',
#   'weird',
#   'daenerys',
#   'knowing',
#   'pregnancy',
#   'telling',
#   'amp',
#   'xb',
#   'dying',
#   'get',
#   'closer',
#   'closer'],
#  ['jon',
#   'arya',
#   'okay',
#   'hbo',
#   'dropped',
#   'one',
#   'two',
#   'promos',
#   'show',
#   'new',
#   'footage',
#   'much',
#   'confirm',
#   'frikis',
#   'leak',
#   'debunks',
#   'leak',
#   'though',
#   'tell',
#   'however',
#   'one',
#   'everyone',
#   'talking',
#   'second',
#   'promo',
#   'first',
#   'shot',
#   'see',
#   'jon',
#   'weirwood',
#   'jon',
#   'looking',
#   'tree',
#   'arya',
#   'right',
#   'behind',
#   'weird',
#   'promotional',
#   'footage',
#   'since',
#   'thought',
#   'may',
#   'want',
#   'reveal',
#   'yet',
#   'make',
#   'wonder',
#   'important',
#   'bond',
#   'actually',
#   'cool',
#   'finally',
#   'see',
#   'two',
#   'together',
#   'long',
#   'people',
#   'think',
#   'actual',
#   'reunion',
#   'dont',
#   'think',
#   'believe',
#   'courtyard',
#   'arya',
#   'return',
#   'people',
#   'wintertown',
#   'even',
#   'case',
#   'still',
#   'dont',
#   'think',
#   'think',
#   'episode',
#   'two',
#   'jon',
#   'learns',
#   'truth',
#   'arya',
#   'come',
#   'comfort',
#   'meaning',
#   'may',
#   'found',
#   'maybe',
#   'heard',
#   'sam',
#   'revealing',
#   'may',
#   'went',
#   'get',
#   'confirmation',
#   'bran',
#   'jon',
#   'promo',
#   'look',
#   'like',
#   'got',
#   'back',
#   'hearing',
#   'something',
#   'didnt',
#   'want',
#   'hear',
#   'arya',
#   'look',
#   'alittle',
#   'well',
#   'feel',
#   'arya',
#   'comfort',
#   'jon',
#   'reveal',
#   'maybe',
#   'tell',
#   'ned',
#   'starks',
#   'son',
#   'stark',
#   'also',
#   'protect',
#   'maybe',
#   'also',
#   'reassures',
#   'always',
#   'see',
#   'big',
#   'brother',
#   'big',
#   'brother',
#   'basically',
#   'similar',
#   'jon',
#   'convo',
#   'theon',
#   'last',
#   'season',
#   'greyjoy',
#   'stark',
#   'let',
#   'hope',
#   'one',
#   'blow',
#   'proportion',
#   'say',
#   'confirms',
#   'jonrya',
#   'stupid',
#   'shit',
#   'insert',
#   'clip',
#   'scar',
#   'lion',
#   'king',
#   'saying',
#   'surrounded',
#   'idiot',
#   'saying',
#   'jonrya',
#   'people',
#   'try',
#   'use',
#   'tease',
#   'excuse',
#   'evidence',
#   'either',
#   'way',
#   'glad',
#   'see',
#   'lady',
#   'kaysen',
#   'right'],
#  ['definitely',
#   'think',
#   'darker',
#   'outfit',
#   'scene',
#   'implying',
#   'danaerys',
#   'mourning',
#   'someone',
#   'maybe',
#   'jorah'],
#  ['bastard', 'owes', 'dad'],
#  ['definitely',
#   'think',
#   'darker',
#   'outfit',
#   'danaerys',
#   'wearing',
#   'implying',
#   'mourning',
#   'someone',
#   'maybe',
#   'jorah'],
#  ['new',
#   'word',
#   'jaime',
#   'first',
#   'thought',
#   'screaming',
#   'run',
#   'others',
#   'thought',
#   'bronn',
#   'another',
#   'translation',
#   'saying',
#   'draw',
#   'think',
#   'saying',
#   'wall',
#   'something',
#   'coming',
#   'wall'],
#  ['new', 'promo', 'trailer', 'find', 'youtube'],
#  ['second', 'promo'],
#  ['going', 'cut', 'loses', 'battle'],
#  ['assuming',
#   'winterfell',
#   'get',
#   'destroyed',
#   'jon',
#   'dany',
#   'escape',
#   'enough',
#   'force',
#   'fight',
#   'another',
#   'day',
#   'based',
#   'leaked',
#   'set',
#   'photo',
#   'analysis',
#   'trailer',
#   'frame',
#   'seems',
#   'like',
#   'u',
#   'agree',
#   'winterfell',
#   'get',
#   'destroyed',
#   'battle',
#   'winterfell',
#   'wondering',
#   'anyone',
#   'theory',
#   'story',
#   'progress',
#   'seems',
#   'like',
#   'north',
#   'beat',
#   'nk',
#   'win',
#   'war',
#   'attrition',
#   'castle',
#   'army',
#   'dead',
#   'north',
#   'attempt',
#   'recover',
#   'jon',
#   'dany',
#   'turn',
#   'south',
#   'left',
#   'army',
#   'main',
#   'reason',
#   'think',
#   'nk',
#   'get',
#   'defeated',
#   'winterfell',
#   'hard',
#   'time',
#   'believing',
#   'army',
#   'defending',
#   'winterfell',
#   'anywhere',
#   'retreat',
#   'entrenched',
#   'position',
#   'outside',
#   'story',
#   'buzz',
#   'night',
#   'shooting',
#   'battle',
#   'going',
#   'longest',
#   'battle',
#   'sequence',
#   'movie',
#   'television',
#   'seem',
#   'likely',
#   'battle',
#   'epic',
#   'scale',
#   'conclude',
#   'definitive',
#   'outcome',
#   'hand',
#   'maybe',
#   'gold',
#   'medal',
#   'javelin',
#   'olympian',
#   'trick',
#   'sleeve',
#   'vladimir',
#   'furdik',
#   'stated',
#   'night',
#   'king',
#   'specific',
#   'target',
#   'seem',
#   'able',
#   'agree',
#   'either',
#   'bran',
#   'likely',
#   'jon',
#   'assuming',
#   'bran',
#   'perhaps',
#   'function',
#   'last',
#   'minute',
#   'diversion',
#   'spare',
#   'northern',
#   'dany',
#   'force',
#   'last',
#   'minute',
#   'tin',
#   'foil',
#   'maybe',
#   'winterfell',
#   'get',
#   'destroyed',
#   'nk',
#   'dy',
#   'nowhere',
#   'stay',
#   'northern',
#   'army',
#   'march',
#   'south',
#   'dany',
#   'jon',
#   'take',
#   'army',
#   'fleet',
#   'dragonstone',
#   'army',
#   'completely',
#   'surround',
#   'king',
#   'landing',
#   'final',
#   'battle',
#   'episode',
#   'could',
#   'wrong',
#   'might',
#   'reading',
#   'wrong',
#   'comment',
#   'hard',
#   'time',
#   'currently',
#   'seeing',
#   'winterfell',
#   'get',
#   'destroyed',
#   'night',
#   'king',
#   'life',
#   'handful',
#   'main',
#   'cast',
#   'winterfell',
#   'survives',
#   'maybe',
#   'missing',
#   'something',
#   'overthinking',
#   'late',
#   'night',
#   'probably',
#   'studying'],
#  ['rumor',
#   'amp',
#   'game',
#   'throne',
#   'creator',
#   'george',
#   'r',
#   'r',
#   'martin',
#   'teaming',
#   'new',
#   'game'],
#  ['slightly', 'lightened', 'picture', 'dany', 'new', 'promo'],
#  ['brooding'],
#  ['outfit', 'come', 'play'],
#  ['soon'],
#  ['definitely',
#   'dragonstone',
#   'aftermath',
#   'winterfell',
#   'war',
#   'maybe',
#   'end',
#   'scene',
#   'dany',
#   'character',
#   'distress',
#   'tyrion',
#   'betrayed',
#   'execute'],
#  ['definitely',
#   'dragonstone',
#   'aftermath',
#   'winterfell',
#   'war',
#   'maybe',
#   'end',
#   'scene',
#   'dany',
#   'character',
#   'distress',
#   'tyrion',
#   'betrayed',
#   'execute'],
#  ['season', 'best', 'quality', 'think'],
#  ['tyrion', 'betray', 'dany', 'dragon', 'lannisters'],
#  ['anyone',
#   'else',
#   'notice',
#   'gold',
#   'hand',
#   'king',
#   'pin',
#   'tyrion',
#   'got',
#   'trailer',
#   'daenerys',
#   'silver',
#   'one',
#   'made',
#   'theory'],
#  ['🤯'],
#  ['simple', 'meme', 'provide', 'short', 'break', 'teaser', 'analysis'],
#  ['people', 'still', 'believe'],
#  ['game', 'throne', 'season', 'impression'],
#  ['everybody',
#   'bottle',
#   'real',
#   'let',
#   'tell',
#   'ya',
#   'real',
#   'reunites',
#   'two',
#   'true'],
#  ['i’m', 'loop', 'whole', 'frikidoctor', 'thing', 'someone', 'fill'],
#  ['needle', 'longclaw', 'unification', 'theory', 'confirmed'],
#  ['one',
#   'afraid',
#   'another',
#   'dragon',
#   'gonna',
#   'die',
#   'even',
#   'fav',
#   'character',
#   'anymore',
#   'show',
#   'even',
#   'care',
#   'le',
#   'gonna',
#   'die',
#   'live',
#   'end',
#   'sound',
#   'weird',
#   'want',
#   'drogon',
#   'alive',
#   'end',
#   'getting',
#   'anymore',
#   'leak',
#   'season',
#   'seeing',
#   'post',
#   'theorizing',
#   'dragon',
#   'gonna',
#   'die',
#   'make',
#   'afraid',
#   'mean',
#   'much',
#   'problem',
#   'seeing',
#   'rhaegal',
#   'die',
#   'drogon',
#   'c',
#   'mon',
#   'making',
#   'bigger',
#   'introducing',
#   'danys',
#   'flagship',
#   'killing',
#   'end'],
#  ['think',
#   'jon',
#   'snow',
#   'greyworm',
#   'would',
#   'get',
#   'along',
#   'would',
#   'love',
#   'see',
#   'two'],
#  ['scenar',
#   'construction',
#   'changed',
#   'new',
#   'promo',
#   'amp',
#   'xb',
#   'http',
#   'redd',
#   'jpg',
#   'amp',
#   'xb',
#   'winterfell',
#   'gone',
#   'amp',
#   'xb',
#   'everyone',
#   'traveled',
#   'dragonstone',
#   'amp',
#   'xb',
#   'jon',
#   'cersei',
#   'try',
#   'new',
#   'conversation',
#   'left',
#   'dany',
#   'behind',
#   'save',
#   'cersei',
#   'already',
#   'pregnant',
#   'amp',
#   'xb',
#   'cersei',
#   'want',
#   'jon',
#   'bend',
#   'knee',
#   'amp',
#   'xb',
#   'jon',
#   'accepted',
#   'dany',
#   'accept',
#   'season',
#   'need',
#   'help',
#   'amp',
#   'xb',
#   'cersei',
#   'betrayed',
#   'jon',
#   'take',
#   'prissioner',
#   'amp',
#   'xb',
#   'dany',
#   'raven',
#   'cersei',
#   'actually',
#   'like',
#   'ramsy',
#   'jon',
#   'cersei',
#   'sansa',
#   'robb',
#   'amp',
#   'xb',
#   'winterfell',
#   'mine',
#   'come',
#   'see',
#   'jon',
#   'mine',
#   'come',
#   'see',
#   'amp',
#   'xb',
#   'dany',
#   'decided',
#   'attack',
#   'king',
#   'landing',
#   'amp',
#   'xb',
#   'p',
#   'remember',
#   'brandon',
#   'arrived',
#   'kl',
#   'mad',
#   'king',
#   'became',
#   'prissioner',
#   'mad',
#   'king',
#   'invited',
#   'rickard',
#   'kl',
#   'make',
#   'son',
#   'free',
#   'amp',
#   'xb',
#   'mad',
#   'king',
#   'cersei',
#   'lannister',
#   'amp',
#   'xb',
#   'brandon',
#   'jon',
#   'amp',
#   'xb',
#   'rickard',
#   'dany',
#   'amp',
#   'xb'],
#  ['must', 'watch', 'new', 'trailer', 'breakdown'],
#  ['drew', 'north', 'map', 'book', 'world', 'ice', 'amp', 'fire'],
#  ['found', 'gag', 'got', 'death', 'statistic'],
#  ['wake', 'hour', 'trailer'],
#  ['leaked',
#   'summary',
#   'episode',
#   'x',
#   'episode',
#   'open',
#   'jon',
#   'daenarys',
#   'sansa',
#   'sitting',
#   'around',
#   'table',
#   'winterfell',
#   'tyrion',
#   'walk',
#   'varys',
#   'begin',
#   'talk',
#   'daenarys’',
#   'dragon',
#   'suddenly',
#   'realize',
#   'way',
#   'short',
#   'real',
#   'episode',
#   'summary',
#   'april',
#   'fool',
#   'ya',
#   'fookin',
#   'cunt'],
#  ['reverse',
#   'scene',
#   'way',
#   'jon',
#   'back',
#   'look',
#   'weird',
#   'one',
#   'look',
#   'natural'],
#  ['reverse',
#   'scene',
#   'way',
#   'jon',
#   'back',
#   'look',
#   'weird',
#   'one',
#   'look',
#   'natural'],
#  ['braid',
#   'kingdom',
#   'amp',
#   'xb',
#   'http',
#   'redd',
#   'png',
#   'braid',
#   'kingdom',
#   'dany',
#   'wearing',
#   'crown',
#   'braid',
#   'crown',
#   'braid',
#   'power',
#   'look',
#   'braid',
#   'seven',
#   'together',
#   'interesting'],
#  ['acronym', 'go', 'head'],
#  ['finally', 'confirmed', 'appearance', 'second', 'promo'],
#  ['jaime’s',
#   'yelling',
#   'promo',
#   'much',
#   'clearer',
#   'trailer',
#   'it’s',
#   'definitely',
#   '”',
#   'initially',
#   'thought',
#   'bronn',
#   'think',
#   'it’s',
#   'draw'],
#  ['two', 'major', 'prophecy', 'discussed', 'citadel', 'maesters'],
#  ['jon',
#   'dany',
#   'arya',
#   'rhe',
#   'familiar',
#   'triangle',
#   'http',
#   'radikal',
#   'ru',
#   'b',
#   'jpg',
#   'jon',
#   'dany',
#   'reunion',
#   'winterfell',
#   'crypt',
#   'jon',
#   'arya',
#   'reunion',
#   'two',
#   'familiar',
#   'place',
#   'starks',
#   'think',
#   'detail',
#   'accidentally'],
#  ['finally', 'wait', 'nearly'],
#  ['game', 'throne', 'season', 'new', 'tv', 'spot', 'hd'],
#  ['game', 'throne', 'season', 'new', 'tv', 'spot', 'hd'],
#  ['fookin',
#   'day',
#   'wake',
#   'every',
#   'day',
#   'pray',
#   'another',
#   'leak',
#   'day',
#   'long',
#   'night',
#   'cold',
#   'leak',
#   'ease',
#   'wait',
#   'pain',
#   'fookin',
#   'day'],
#  ['lannister', 'propaganda', 'context'],
#  ['new',
#   'theory',
#   'brienne',
#   'faceless',
#   'stannis',
#   'really',
#   'think',
#   'going',
#   'kill',
#   'boy',
#   'stannis',
#   'screen',
#   'stannis',
#   'rightful',
#   'heir',
#   'ruler',
#   'westeros',
#   'think',
#   'brienne',
#   'kill',
#   'stannis',
#   'think',
#   'stannis',
#   'managed',
#   'kill',
#   'brienne',
#   'wearing',
#   'face',
#   'fact',
#   'stannis',
#   'went',
#   'esos',
#   'talk',
#   'iron',
#   'bank',
#   'hire',
#   'men',
#   'else',
#   'esos',
#   'right',
#   'faceless',
#   'men',
#   'hired',
#   'right',
#   'faceless',
#   'men',
#   'like',
#   'use',
#   'magic',
#   'demon',
#   'evil',
#   'thing',
#   'right',
#   'stannis',
#   'man',
#   'boy',
#   'stannis',
#   'playing',
#   'long',
#   'game',
#   'even',
#   'going',
#   'fuck',
#   'jamie',
#   'kill',
#   'mid',
#   'coitus',
#   'oathkeeper',
#   'care',
#   'jon',
#   'something',
#   'stannis',
#   'rightful',
#   'heir',
#   'bobby',
#   'b',
#   'ask',
#   'confirm',
#   'brienne',
#   'told',
#   'davos',
#   'melisandre',
#   'killed',
#   'stannis',
#   'check',
#   'loyalty',
#   'see',
#   'reaction',
#   'know',
#   'mel',
#   'hound',
#   'stannis',
#   'going',
#   'kill',
#   'weird',
#   'brienne',
#   'loyal',
#   'daughter',
#   'man',
#   'gave',
#   'life',
#   'name',
#   'stannis',
#   'lawful',
#   'rightful',
#   'heir',
#   'long',
#   'story',
#   'shirt',
#   'stannis',
#   'alive',
#   'faceless',
#   'c',
#   'n',
#   'f',
#   'r',
#   'e',
#   'amp',
#   'xb',
#   'amp',
#   'xb'],
#  ['braavos',
#   'may',
#   'hear',
#   'dead',
#   'may',
#   'even',
#   'true',
#   'shall',
#   'find',
#   'sellswords',
#   'nonetheless',
#   'knight',
#   'hesitated',
#   'grace',
#   'dead',
#   '—',
#   '—',
#   'avenge',
#   'death',
#   'seat',
#   'daughter',
#   'iron',
#   'throne',
#   'die',
#   'attempt'],
#  ['spot', 'rewatch', 'even', 'knowing', 'coming', 'shocking', 'hard', 'hit'],
#  ['dragon',
#   'glass',
#   'winterfell',
#   'look',
#   'like',
#   'got',
#   'enough',
#   'dragon',
#   'glass',
#   'make',
#   'fair',
#   'fight'],
#  ['jon', 'snow', 'aegon'],
#  ['daily',
#   'r',
#   'freefolk',
#   'free',
#   'talk',
#   'thread',
#   'april',
#   'daily',
#   'free',
#   'talk',
#   'thread',
#   'feel',
#   'free',
#   'discus',
#   'whatever',
#   'like'],
#  ['hour',
#   'pf',
#   'reading',
#   'evidence',
#   'jonsa',
#   'admit',
#   'probable',
#   'jonsa',
#   'happen',
#   'please',
#   'tell',
#   'fall'],
#  ['day', 'quote', 'day'],
#  ['watch', 'got', 'season', 'india', 'hotstar'],
#  ['gonna', 'cry', 'shit', 'scene'],
#  ['people', 'drill', 'finally', 'april'],
#  ['face'],
#  ['people', 'drill', 'finally', 'april'],
#  ['dany',
#   'tyrion',
#   'betrayal',
#   'betrayal',
#   'else',
#   'may',
#   'betray',
#   'dany',
#   'varys',
#   'maybe'],
#  ['pink', 'composed', 'game', 'throne'],
#  ['jon',
#   'arya',
#   'dany',
#   'jorah',
#   'parallel',
#   'scene',
#   'http',
#   'radikal',
#   'ru',
#   'cd',
#   'jpg',
#   'jon',
#   'arya',
#   'dany',
#   'jorah',
#   'parallel',
#   'scene',
#   'suffer',
#   'parentage',
#   'news'],
#  [],
#  ['who’s', 'face', 'foreground', 'see', 'beric', 'sword', 'davos'],
#  ['devil', 'angel'],
#  ['asia',
#   'watch',
#   'game',
#   'throne',
#   'season',
#   'air',
#   'get',
#   'hbo',
#   'cable',
#   'tv',
#   'possible',
#   'way',
#   'watch',
#   'without',
#   'pirating',
#   'use',
#   'vpn',
#   'get',
#   'hbo',
#   'sub',
#   'either',
#   'coz',
#   'accept',
#   'u',
#   'card',
#   'work',
#   'go',
#   'pirate'],
#  ['feel',
#   'made',
#   'daenerys',
#   'look',
#   'like',
#   'barbie',
#   'doll',
#   'picture',
#   'soft',
#   'fragile'],
#  ['person',
#   'would',
#   'see',
#   'episode',
#   'week',
#   'aired',
#   'season',
#   'leaked',
#   'detail',
#   'think',
#   'eventually',
#   'leaked',
#   'whole',
#   'season',
#   'even',
#   'though',
#   'knew',
#   'anyways',
#   'whoever',
#   'can’t',
#   'remember',
#   'hope',
#   'come',
#   'back'],
#  ['night',
#   'king',
#   'happy',
#   'living',
#   'can’t',
#   'escape',
#   'winterfell',
#   'water'],
#  ['favorite', 'quote', 'game', 'throne'],
#  ['april',
#   'fool',
#   'last',
#   'year',
#   'remembers',
#   'april',
#   'fool',
#   'last',
#   'year',
#   'everybody',
#   'pretended',
#   'jonsa',
#   'stan',
#   'shit',
#   'funny',
#   'fuck'],
#  ['kit',
#   'harington',
#   'flexing',
#   'new',
#   'house',
#   'stark',
#   'coupled',
#   'fact',
#   'said',
#   'wanted',
#   'stark',
#   'tattoo',
#   'finishing',
#   'filming',
#   'something',
#   'clicking',
#   'http',
#   'imgur',
#   'com',
#   'jpg'],
#  [],
#  ['look',
#   'like',
#   'daenerys',
#   'starting',
#   'dress',
#   'even',
#   'like',
#   'targaryen',
#   'brother'],
#  ['look',
#   'like',
#   'daenerys',
#   'starting',
#   'dress',
#   'even',
#   'like',
#   'targaryen',
#   'brother'],
#  ['look',
#   'like',
#   'dany',
#   'starting',
#   'dress',
#   'even',
#   'like',
#   'targaryen',
#   'brother'],
#  ['course', 'university'],
#  ['see', 'coming'],
#  ['inside', 'source', 'davos', 'go', 'winter', 'zombie', 'steal', 'onion'],
#  ['inside',
#   'source',
#   'davos',
#   'go',
#   'undercover',
#   'winter',
#   'zombie',
#   'steal',
#   'onion'],
#  ['isaac', 'wrapped', 'spain'],
#  ['wish',
#   'first',
#   'season',
#   'interactive',
#   'started',
#   'rewatch',
#   'help',
#   'wish',
#   'need',
#   'thing',
#   'little',
#   'differently',
#   'heart',
#   'hope',
#   'know',
#   'shattered'],
#  ['castle',
#   'black',
#   'survivor',
#   'friki’s',
#   'e',
#   'summary',
#   'said',
#   'aotd',
#   'arrive',
#   'cb',
#   'personally',
#   'can’t',
#   'see',
#   'anybody',
#   'surviving',
#   'must',
#   'plot',
#   'purpose',
#   'showing',
#   'aotd',
#   'cb',
#   'bet',
#   'nw',
#   'completely',
#   'wiped',
#   'might',
#   'see',
#   'edd',
#   'wight',
#   'latest',
#   'teaser',
#   'hear',
#   'jon',
#   'say',
#   'probably',
#   'sam',
#   'u',
#   'also',
#   'make',
#   'think',
#   'whole',
#   'nw',
#   'gone',
#   'teaser',
#   'see',
#   'beric',
#   'know',
#   'cb',
#   'could',
#   'beric',
#   'fighting',
#   'cb',
#   'instead',
#   'wf',
#   'teaser',
#   'he’s',
#   'fire',
#   'wight',
#   'beric',
#   'survive',
#   'aotd',
#   'cb',
#   'make',
#   'wf',
#   'could',
#   'beric',
#   'perhaps',
#   'tormund',
#   'edd',
#   'leave',
#   'wf',
#   'aotd',
#   'arrive',
#   'cb'],
#  ['cool', 'motive', 'still', 'murder'],
#  ['sam', 'dany', '😂'],
#  ['jon',
#   'snow',
#   'isn’t',
#   'love',
#   'http',
#   'radikal',
#   'ru',
#   'da',
#   'jpg',
#   'jon’s',
#   'child',
#   'blame',
#   'everything',
#   'ro',
#   'amp',
#   'absolutely',
#   'genial',
#   'creator',
#   'construction'],
#  ['watch', 'tv', 'spot', 'hd'],
#  ['day', 'second', 'quote', 'day'],
#  ['yep', 'definitely', 'dragonstone'],
#  ['shitpost'],
#  ['one',
#   'wearing',
#   'hat',
#   'keep',
#   'thinking',
#   'cold',
#   'ear',
#   'must',
#   'get',
#   'someone',
#   'please',
#   'get',
#   'varys',
#   'hat',
#   'feel',
#   'bad',
#   'annoys',
#   'lot'],
#  ['treason',
#   'sansa',
#   'lie',
#   'council',
#   'vale',
#   'came',
#   'mind',
#   'idea',
#   'sansa',
#   'committed',
#   'treason',
#   'lied',
#   'folk',
#   'vale',
#   'lysa',
#   'death',
#   'wondering',
#   'would',
#   'repercussion',
#   'mean',
#   'scene',
#   'lf',
#   'death',
#   'kinda',
#   'admits',
#   'front',
#   'ser',
#   'royce',
#   'saying',
#   'know',
#   'lf',
#   'killed',
#   'lysa',
#   'would',
#   'ser',
#   'royce',
#   'stay',
#   'loyal',
#   'maybe',
#   'talk',
#   'offscreen',
#   'know',
#   'whole',
#   'lf',
#   'trial',
#   'pretty',
#   'inconsistent',
#   'wondering',
#   'clear',
#   'somehow',
#   'really',
#   'expect',
#   'series',
#   'address'],
#  ['jon', 'wearing', 'dragon', 'pin'],
#  ['red',
#   'carpet',
#   'premiere',
#   'http',
#   'www',
#   'instagram',
#   'com',
#   'p',
#   'utm',
#   'source',
#   'ig',
#   'share',
#   'sheet',
#   'amp',
#   'igshid',
#   'pilou',
#   'way',
#   'nyc',
#   'john',
#   'bradley',
#   'liked',
#   'post',
#   'well',
#   'must',
#   'red',
#   'carpet',
#   'premiere',
#   'wednesday',
#   'night',
#   'hopefully',
#   'get',
#   'premeire',
#   'episode',
#   'title'],
#  ['leaked', 'backstage', 'scene', 'season', 'jon', 'melisandre', 'omg', '😮'],
#  ['shocking', 'death', 'caused', 'george', 'r', 'r', 'martin', 'expecting'],
#  ['way', 'satisfy', 'sub'],
#  ['dany', 'winterfell', 'throne', 'room', 'like'],
#  ['westeros',
#   'lose',
#   'battle',
#   'winterfell',
#   'rd',
#   'episode',
#   'episode',
#   'left',
#   'like',
#   'infinity',
#   'war',
#   'good',
#   'guy',
#   'lose',
#   'difference',
#   'dead',
#   'good',
#   'guy',
#   'return',
#   'episode',
#   'infinity',
#   'war',
#   'style',
#   'episode',
#   'engame',
#   'style'],
#  ['first', 'time', 'brain', 'get', 'fucked'],
#  ['tormund', 'looking', 'dapper', 'af'],
#  ['season',
#   'episode',
#   'leak',
#   'read',
#   'somewhere',
#   'facebook',
#   'se',
#   'leaked',
#   'true'],
#  ['friki', 'respect', 'brother'],
#  ['game', 'throne', 'season', 'impression'],
#  ['kit',
#   'harington',
#   'arrives',
#   'evening',
#   'show',
#   'russia',
#   'http',
#   'www',
#   'instagram',
#   'com',
#   'p',
#   'http',
#   'www',
#   'instagram',
#   'com',
#   'p',
#   'http',
#   'redd',
#   'jpg'],
#  ['known', 'animal', 'susceptible', 'warging'],
#  ['outstanding', 'move'],
#  ['season', 'year', 'borrowed', 'tumblr'],
#  ['daenerys',
#   'final',
#   'battle',
#   'stark’s',
#   'double',
#   'cross',
#   'dany',
#   'battle',
#   'winterfell',
#   'stark’s',
#   'conveniently',
#   'lock',
#   'unsullied',
#   'dothraki',
#   'outside',
#   'gate',
#   'die',
#   'even',
#   'knight',
#   'vale',
#   'also',
#   'face',
#   'doom',
#   'dany',
#   'retreat',
#   'dragonstone',
#   'realize',
#   'ultimate',
#   'betrayal',
#   'called',
#   'ally',
#   'finally',
#   'accepts',
#   'true',
#   'nature',
#   'become',
#   'conqueror',
#   'go',
#   'full',
#   'fire',
#   'blood',
#   'kl',
#   'predict',
#   'jon',
#   'dany’s',
#   'relationship',
#   'even',
#   'arya',
#   'try',
#   'best',
#   'bridge',
#   'two',
#   'damaged',
#   'dany',
#   'dragon',
#   'die',
#   'kl',
#   'taking',
#   'mad',
#   'queen',
#   'cersei',
#   'die',
#   'horrible',
#   'death',
#   'hand',
#   'dany’s',
#   'dragon',
#   'jon',
#   'accept',
#   'destiny',
#   'final',
#   'battle',
#   'defeat',
#   'nk',
#   'dy',
#   'injury',
#   'cleganebowl',
#   'happen',
#   'hero',
#   'mortally',
#   'injured',
#   'arya',
#   'give',
#   'sandor',
#   'mercy',
#   'escape',
#   'collapse',
#   'loss',
#   'blood',
#   'nymeria',
#   'approach',
#   'dying',
#   'arya',
#   'wargs',
#   'nymeria',
#   'becomes',
#   'one',
#   'pack',
#   'stark’s',
#   'become',
#   'new',
#   'villain',
#   'they’re',
#   'victory',
#   'short',
#   'lived',
#   'house',
#   'extinct',
#   'sansa',
#   'pronounces',
#   'judgement',
#   'brutalized',
#   'tyrion',
#   'tyrion',
#   'blow',
#   'dragonpit',
#   'taking',
#   'everyone',
#   'westeros',
#   'wasteland',
#   'population',
#   'gone',
#   'much',
#   'like',
#   'old',
#   'valyria',
#   'story',
#   'told',
#   'pov',
#   'sam',
#   'gilly',
#   'child',
#   'refugee',
#   'essos'],
#  ['leaked',
#   'scene',
#   'i’m',
#   'reading',
#   'facebook',
#   'leaked',
#   'scene',
#   'apparently',
#   'people',
#   'keep',
#   'trying',
#   'post',
#   'fb',
#   'group',
#   'i’m',
#   'it’s',
#   'group',
#   'i’m',
#   'guessing',
#   'isn’t',
#   'translated',
#   'recap',
#   'specifically',
#   'said',
#   'scene',
#   'anyone',
#   'care',
#   'share'],
#  ['omg'],
#  ['it’s',
#   'traditional',
#   'field',
#   'post',
#   'paper',
#   'april',
#   'fool',
#   'day',
#   'thought',
#   'many',
#   'might',
#   'interested',
#   'though',
#   '“the',
#   'long',
#   'night',
#   'modeling',
#   'climate',
#   'westeros”'],
#  ['hbo',
#   'official',
#   'hq',
#   'version',
#   'two',
#   'new',
#   'teaser',
#   'taken',
#   'official',
#   'hq',
#   'teaser',
#   'available',
#   'youtube',
#   'twenty',
#   'minute',
#   'video',
#   'blocked',
#   'sudden',
#   'link',
#   'screenshot',
#   'http',
#   'imgur',
#   'com',
#   'jpg'],
#  ['following', 'lannister', 'way'],
#  ['happy', 'april', 'st', 'r', 'freefolk'],
#  [],
#  ['reliable',
#   'leak',
#   'reliable',
#   'leak',
#   'far',
#   'get',
#   'read',
#   'trying',
#   'forgot'],
#  ['got',
#   'leaked',
#   'info',
#   'jon',
#   'arya',
#   'scene',
#   'promo',
#   'time',
#   'april',
#   'fool',
#   'okay',
#   'source',
#   'told',
#   'moment',
#   'jon',
#   'arya',
#   'confess',
#   'love',
#   'one',
#   'another',
#   'kiss',
#   'cut',
#   'sex',
#   'scene',
#   'two',
#   'sansa',
#   'catch',
#   'two',
#   'reveals',
#   'jon',
#   'well',
#   'ask',
#   'join',
#   'yep',
#   'get',
#   'threesome',
#   'jon',
#   'arya',
#   'sansa',
#   'season'],
#  ['someone',
#   'picked',
#   'teaser',
#   'must',
#   'say',
#   'got',
#   'really',
#   'sharp',
#   'eye',
#   'look',
#   'like',
#   'targaryen',
#   'pin',
#   'similar',
#   'daenerys'],
#  ['able', 'identify'],
#  ['yay'],
#  ['reunion', 'waiting'],
#  ['ouch'],
#  ['guy',
#   'think',
#   'emilia',
#   'one',
#   'get',
#   'special',
#   'costume',
#   'designer',
#   'significant',
#   'wonder',
#   'what’s',
#   'special',
#   'dany’s',
#   'outfit',
#   'season'],
#  ['title'],
#  ['tormund', 'drawing', 'anna'],
#  ['season', 'plot', 'twist', 'leaked'],
#  ['“it',
#   'it’s',
#   'always',
#   'you”',
#   'jon',
#   'whispered',
#   'staring',
#   'eye',
#   'eye',
#   'blue',
#   'sweet',
#   'winter',
#   'rose'],
#  ['leak',
#   'sub',
#   'super',
#   'legit',
#   'quick',
#   'question',
#   'lad',
#   'browsing',
#   'sub',
#   'accidentally',
#   'saw',
#   'comment',
#   'big',
#   'based',
#   'post',
#   'haven’t',
#   'read',
#   'post',
#   'don’t',
#   'intend',
#   'got',
#   'sub',
#   'like',
#   'anyone',
#   'asks',
#   'i’m',
#   'browsing',
#   'instead',
#   'others',
#   'wanna',
#   'know',
#   'leak',
#   'previous',
#   'season',
#   'legit',
#   'right',
#   'can’t',
#   'stop',
#   'thinking',
#   'whether',
#   'it’s',
#   'true',
#   'won’t',
#   'say',
#   'exactly',
#   'referring',
#   'jaime'],
#  ['hope',
#   'network',
#   'name',
#   'house',
#   'lannister',
#   'men',
#   'must',
#   'wifi',
#   'approve',
#   'mine'],
#  ['people',
#   'still',
#   'seriously',
#   'want',
#   'bring',
#   'ridiculous',
#   'arya',
#   'waif',
#   'theory'],
#  ['jon', '“now', 'us”', 'talking', 'sam', 'daenerys'],
#  ['aware', 'pregnancy', 'point'],
#  ['hero', 'go', 'quite', 'little', 'tyrion'],
#  ['inside',
#   'game',
#   'throne',
#   'story',
#   'visual',
#   'effect',
#   'bts',
#   'hbo',
#   'http',
#   'youtu'],
#  ['average', 'argument'],
#  ['finally', 'two', 'year', 'quality', 'footage', 'dissect'],
#  ['moment',
#   'made',
#   'go',
#   'oh',
#   'get',
#   'could',
#   'see',
#   'series',
#   'going',
#   'people',
#   'may',
#   'picked',
#   'old',
#   'ned',
#   'lost',
#   'head',
#   'personally',
#   'think',
#   'took',
#   'red',
#   'wedding',
#   'moment',
#   'looking',
#   'bigger',
#   'picture',
#   'thought',
#   '“if',
#   'keep',
#   'killing',
#   'favourite',
#   'main',
#   'character',
#   'show',
#   'going',
#   '”',
#   'remember',
#   'exact',
#   'discussion',
#   'husband',
#   'red',
#   'wedding',
#   'said',
#   'ok',
#   'bran',
#   'sam',
#   'wizard',
#   'arya',
#   'get',
#   'training',
#   'ninja',
#   'knight',
#   'dany',
#   'make',
#   'westeros',
#   'final',
#   'fight',
#   'jon',
#   'white',
#   'walker',
#   'mother',
#   'anyway',
#   'everyone',
#   'else',
#   'figure',
#   'wasn’t',
#   'robb',
#   'ned',
#   'etc',
#   'fool',
#   'waited',
#   'red',
#   'wedding',
#   '“get',
#   'it”'],
#  ['alt', 'shift', 'x', 'game', 'throne', 'season', 'explained'],
#  ['costume', 'seen', 'far', 'favorite', 'along', 'cersei', 'red', 'dress'],
#  ['thank',
#   'u',
#   'cleverdvil',
#   'video',
#   'part',
#   'slo',
#   'mo',
#   'doesn’t',
#   'love',
#   'dragon',
#   'flying'],
#  ['make', 'april', 'fool', 'day', 'post', 'single', 'person', 'understands'],
#  ['please', 'listen', 'guy', 'hbo'],
#  ['sam',
#   'deserted',
#   'night',
#   'watch',
#   'jon',
#   'behead',
#   'return',
#   'winterfell',
#   'would',
#   'twist'],
#  ['hound',
#   'season',
#   'frikidoctor',
#   'promo',
#   'last',
#   'night',
#   'told',
#   'u',
#   'lot',
#   'path',
#   'season',
#   'know',
#   'episode',
#   'tell',
#   'arya',
#   'should’ve',
#   'granted',
#   'mercy',
#   'se',
#   'learned',
#   'yesterday',
#   'sandor',
#   'repeat',
#   'panic',
#   'attack',
#   'like',
#   'battle',
#   'black',
#   'water',
#   'bay',
#   'fear',
#   'fire',
#   'think',
#   'it’s',
#   'pretty',
#   'clear',
#   'hound’s',
#   'story',
#   'end',
#   'overcomes',
#   'fear',
#   'fire',
#   'probably',
#   'using',
#   'fire',
#   'brother',
#   'get',
#   'gravely',
#   'injured',
#   'arya',
#   'grant',
#   'mercy'],
#  ['finally', 'able', 'get', 'pic', 'longclaw', 'better', 'light'],
#  ['thanks', 'u', 'cleverdvil', 'video', 'part', 'promo', 'part', 'slo', 'mo'],
#  ['trailer', 'dark', 'still', 'full'],
#  ['prepared',
#   'picked',
#   'dragon',
#   'glass',
#   'dagger',
#   'obsidian',
#   'found',
#   'mexico',
#   'taking',
#   'tour',
#   'say',
#   'i’m',
#   'truly',
#   'prepared',
#   'winter',
#   'coming',
#   'fast'],
#  ['vineyard',
#   'made',
#   'wine',
#   'called',
#   '‘the',
#   'yet',
#   'feel',
#   'it’s',
#   'opportunity',
#   'take'],
#  ['think',
#   'godswood',
#   'well',
#   'part',
#   'winterfell',
#   'battle',
#   'thought',
#   'trailer',
#   'teaser',
#   'showed',
#   'log',
#   'scene',
#   'seems',
#   'like',
#   'godswood',
#   'could',
#   'cool',
#   'eye',
#   'storm',
#   'type',
#   'location',
#   'walker',
#   'v',
#   'human',
#   'fight',
#   'dramatic',
#   'death',
#   'happen',
#   'would',
#   'also',
#   'cool',
#   'get',
#   'shot',
#   'main',
#   'weirwood',
#   'tree',
#   'burning',
#   'dying',
#   'underline',
#   'seriousness',
#   'winterfell',
#   'falling'],
#  ['lil', 'finger'],
#  ['one',
#   'time',
#   'true',
#   'king',
#   'freefolk',
#   'long',
#   'live',
#   'therealfrikidoctor'],
#  ['one',
#   'time',
#   'real',
#   'king',
#   'freefolk',
#   'long',
#   'live',
#   'therealfrikidoctor'],
#  ['miss', 'yet'],
#  ['man', 'holding', 'door', 'metro', 'saying', 'hold', 'door'],
#  ['definitely', 'breakup', 'parentage', 'revealed'],
#  ['game', 'throne', 'season', 'explained'],
#  ['dragonstone', 'true', 'two', 'sword'],
#  ['confirmed',
#   'jon',
#   'dany',
#   'least',
#   'together',
#   'start',
#   'i’ve',
#   'seen',
#   'thousand',
#   'meme',
#   'point',
#   'think',
#   'jon',
#   'dany',
#   'basically',
#   'confirmed',
#   'they’ll',
#   'together',
#   'i’m',
#   'holding'],
#  ['duolingo'],
#  ['dead',
#   'alive',
#   'pool',
#   'end',
#   'season',
#   'http',
#   'twitter',
#   'com',
#   'status',
#   'photo',
#   'http',
#   'twitter',
#   'com',
#   'status',
#   'photo',
#   'amp',
#   'xb',
#   'hard',
#   'believe',
#   'say',
#   'everyone',
#   'dead',
#   'walker',
#   'take'],
#  ['hbo',
#   'release',
#   'another',
#   'teaser',
#   'trailer',
#   'without',
#   'bloody',
#   'melisandre',
#   'scene'],
#  ['bran', 'control', 'ice', 'dead', 'wight', 'dragon'],
#  ['we’re', 'almost'],
#  ['definitive',
#   'proof',
#   'jonsa',
#   'real',
#   'go',
#   'http',
#   'cdn',
#   'image',
#   'medium',
#   'com',
#   'max',
#   'jpg'],
#  ['call',
#   'arm',
#   'k',
#   'let',
#   'search',
#   'frikidoctor',
#   'result',
#   'algorithm',
#   'hero',
#   'deserves',
#   'wider',
#   'recognition',
#   'p',
#   'upvotes',
#   'please',
#   'want',
#   'karma',
#   'sub',
#   'wide',
#   'tribute',
#   'someone',
#   'fought',
#   'good',
#   'fight',
#   'real',
#   'life'],
#  ['jonsa',
#   'endgame',
#   'really',
#   'amp',
#   'xb',
#   'best',
#   'delusion',
#   'year',
#   'oscar',
#   'go',
#   'http',
#   'redd',
#   'jpg',
#   'amp',
#   'xb',
#   'wait',
#   'burn',
#   'kl'],
#  ['still',
#   'get',
#   'khals',
#   'running',
#   'cry',
#   'fire',
#   'like',
#   'coward',
#   'kneeler',
#   'ever',
#   'x',
#   'wherever',
#   'khal',
#   'drogo',
#   'hope',
#   'see'],
#  ['hope', 'hbo', 'release', 'picture', 'online'],
#  ['long', 'live', 'frikidoctor'],
#  ['worthy'],
#  ['idea',
#   'jon',
#   'dany',
#   'marry',
#   'know',
#   'she’s',
#   'pregnant',
#   'jon',
#   'doesn’t',
#   'want',
#   'bring',
#   'bastard',
#   'westeros',
#   'marrying',
#   'inevitable',
#   'i’m',
#   'curious',
#   'happens'],
#  ['it´s', 'wolf'],
#  ['parallel', 'scene', 'look', 'emotional'],
#  ['daenerys', 'celebrates', 'ride', 'large', 'cock'],
#  ['required', 'stuntman', 'mean', 'action'],
#  ['hound', 'pant'],
#  ['question',
#   'davos',
#   'sam',
#   'davos',
#   'wasn’t',
#   'blame',
#   'tyrion',
#   'reason',
#   'kill',
#   'son',
#   'son',
#   'good',
#   'boy',
#   'sam',
#   'need',
#   'angry',
#   'dany',
#   'killed',
#   'criminal',
#   'father',
#   'really',
#   'tried',
#   'kill',
#   'sam',
#   'many',
#   'time',
#   '🙄',
#   'logic'],
#  ['feel', 'someone', 'hate'],
#  ['feel', 'someone', 'hate'],
#  ['hope', 'jon', 'dany', 'get', 'married', 'place', 'dragonstone'],
#  ['guy', 'like', 'nk', 'image', 'posted', 'shirt'],
#  ['would',
#   'tywin',
#   'went',
#   'north',
#   'knew',
#   'coming',
#   'would',
#   'done',
#   'jaime',
#   'going',
#   'north',
#   'help',
#   'save',
#   'north',
#   'rest',
#   'kingdom',
#   'coming',
#   'cersei',
#   'leaving',
#   'kill',
#   'sweeping',
#   'take',
#   'control',
#   'although',
#   'tywin',
#   'cold',
#   'mean',
#   'cold',
#   'hearted',
#   'doubt',
#   'would',
#   'stayed',
#   'king',
#   'landing',
#   'casterly',
#   'rock',
#   'hope',
#   'best',
#   'especially',
#   'scenario',
#   'would',
#   'make',
#   'look',
#   'weak',
#   'north',
#   'prevailed',
#   'refused',
#   'help'],
#  ['brotherhood',
#   'without',
#   'manner',
#   'e',
#   'sansa',
#   'girl',
#   'dream',
#   'comedy',
#   'discussion',
#   'read',
#   'brotherhood',
#   'without',
#   'manner',
#   'e',
#   'sansa',
#   'girl',
#   'dream',
#   'http',
#   'withoutmanners',
#   'libsyn',
#   'com',
#   'sansa',
#   'girl',
#   'dream',
#   'nsfw',
#   'website',
#   'http',
#   'withoutmanners',
#   'libsyn',
#   'com',
#   'itunes',
#   'http',
#   'itunes',
#   'apple',
#   'com',
#   'u',
#   'podcast',
#   'brotherhood',
#   'without',
#   'manner',
#   'id',
#   'l',
#   'spotify',
#   'http',
#   'open',
#   'spotify',
#   'com',
#   'show',
#   'ekolulejrypwkbkteu',
#   'r',
#   'http',
#   'withoutmanners',
#   'libsyn',
#   'com',
#   'r',
#   'today',
#   'read',
#   'sansa',
#   'prepares',
#   'wonderful',
#   'day',
#   'tea',
#   'lemon',
#   'cake',
#   'queen',
#   'unexpected',
#   'guest',
#   'prevent',
#   'cersei',
#   'entertaining',
#   'get',
#   'side',
#   'side',
#   'look',
#   'stark',
#   'girl',
#   'different',
#   'truly',
#   'meet',
#   'bad',
#   'as',
#   'barry',
#   'bold',
#   'member',
#   'robert',
#   'court',
#   'sansa',
#   'dream',
#   'date',
#   'prince',
#   'joffrey',
#   'attack',
#   'prince',
#   'course',
#   'give',
#   'weekly',
#   'inductee',
#   'chapter',
#   'twitter',
#   'http',
#   'twitter',
#   'com',
#   'mannerswithout',
#   'facebook',
#   'http',
#   'www',
#   'facebook',
#   'com',
#   'brotherhoodpodcast',
#   'patreon',
#   'http',
#   'www',
#   'patreon',
#   'com',
#   'withoutmanners'],
#  ['new', 'scene', 'analysis', 'talking', 'throne'],
#  ['miss', 'train'],
#  ['reaction', 'someone', 'say'],
#  ['cersei',
#   'finding',
#   'jaime',
#   'really',
#   'left',
#   'find',
#   'podrick',
#   'send',
#   'video',
#   'bronn',
#   'group',
#   'smartphone'],
#  ['melisandre',
#   'need',
#   'sacrifice',
#   'save',
#   'dany',
#   'melisandre',
#   'said',
#   'varys',
#   'need',
#   'come',
#   'back',
#   'dragonstone',
#   'last',
#   'time',
#   'strange',
#   'place',
#   'dy',
#   'dany',
#   'dragonstone',
#   'birth',
#   'baby',
#   'melisandre',
#   'meant',
#   'need',
#   'die',
#   'dragonstone',
#   'jon',
#   'ice',
#   'come',
#   'back',
#   'life',
#   'melisandre',
#   'saved',
#   'it’s',
#   'could',
#   'time',
#   'dany',
#   'fire',
#   'return',
#   'life',
#   'melisandre',
#   'melisandre’s',
#   'death',
#   'pay',
#   'life',
#   '“a',
#   'song',
#   'ice',
#   'fire”'],
#  ['day', 'dark', 'amp', 'full', 'terror'],
#  ['daenerys', 'celebrates', 'ride', 'cock'],
#  ['king', 'north'],
#  ['train', 'drogon', 'poster'],
#  ['shiny', 'blur'],
#  ['someone', 'say', 'jonerys', 'endgame', 'instead', 'jonsa'],
#  ['actor',
#   'interview',
#   'maisie',
#   'supposed',
#   'appear',
#   'tonight',
#   'show',
#   'jimmy',
#   'fallon',
#   'today'],
#  ['new', 'promotional', 'banner', 'campaign'],
#  ['battle',
#   'winterfell',
#   'theory',
#   'lose',
#   'battle',
#   'winterfell',
#   'make',
#   'sense',
#   'way',
#   'anyone',
#   'expect',
#   'daenerys',
#   'jon',
#   'survive',
#   'guess',
#   'could',
#   'potentially',
#   'hide',
#   'crypt',
#   'survive',
#   'sound',
#   'like',
#   'bad',
#   'writing',
#   'two',
#   'option',
#   'night',
#   'king',
#   'army',
#   'split',
#   'majority',
#   'ng',
#   'viserion',
#   'going',
#   'kingslanding',
#   'episode',
#   'could',
#   'actually',
#   'see',
#   'capturing',
#   'twin',
#   'cersei',
#   'preparing',
#   'defend',
#   'king',
#   'landing',
#   'could',
#   'also',
#   'see',
#   'daenerys',
#   'jon',
#   'everyone',
#   'else',
#   'sail',
#   'dragonstone',
#   'probably',
#   'making',
#   'decision',
#   'whether',
#   'help',
#   'cersei',
#   'go',
#   'essos',
#   'unsullied',
#   'lose',
#   'battle',
#   'field',
#   'winterfell',
#   'becomes',
#   'certain',
#   'winterfell',
#   'lost',
#   'jon',
#   'daenerys',
#   'decide',
#   'leave',
#   'go',
#   'dragonstone',
#   'probably',
#   'afraid',
#   'losing',
#   'dragon',
#   'leave',
#   'arya',
#   'jamie',
#   'wilding',
#   'others',
#   'still',
#   'trying',
#   'defend',
#   'main',
#   'castle',
#   'end',
#   'episode',
#   'cersei',
#   'army',
#   'surprisingly',
#   'arrives',
#   'destroy',
#   'night',
#   'king',
#   'army',
#   'also',
#   'forced',
#   'go',
#   'back',
#   'viserion',
#   'quburn',
#   'secret',
#   'weapon',
#   'could',
#   'potentially',
#   'also',
#   'wound',
#   'viserion',
#   'everyone',
#   'winterfell',
#   'become',
#   'cersei',
#   'hostage',
#   'turn',
#   'tyrion',
#   'knew',
#   'time',
#   'everyone',
#   'think',
#   'could',
#   'potentially',
#   'face',
#   'second',
#   'trial',
#   'crime',
#   'commit'],
#  ['braime', 'learning', 'make', 'decision', 'equal'],
#  ['full', 'fountain', 'show', 'bellagio'],
#  ['last', 'night', 'leak', 'dark', 'full', 'shipping'],
#  ['yes', 'bran', 'know'],
#  ['«',
#   'lost',
#   'first',
#   'boy',
#   'black',
#   'haired',
#   'beauty',
#   'boy',
#   'looked',
#   'like',
#   'little',
#   'thing',
#   'bird',
#   'without',
#   'feather',
#   'took',
#   'away',
#   'never',
#   'saw',
#   '»',
#   'cersei',
#   'ep',
#   'got',
#   'rewatch'],
#  ['winterfell', 'dug', 'trench', 'around'],
#  ['time',
#   'wheel',
#   '“wheel',
#   'weave',
#   'wheel',
#   'jon',
#   'rand',
#   'al',
#   'thor',
#   'make',
#   'dany',
#   'elayne',
#   'freefolk',
#   'aiel'],
#  ['we’re',
#   'close',
#   'premiere',
#   'guy',
#   'actually',
#   'want',
#   'read',
#   'love',
#   'sub',
#   'coming',
#   'last',
#   'couple',
#   'season',
#   'get',
#   'fix',
#   'time',
#   'read',
#   'book',
#   'didn’t',
#   'care',
#   'much',
#   'kinda',
#   'thing',
#   'know',
#   'what’s',
#   'gonna',
#   'happen',
#   'actually',
#   'seeing',
#   'reason',
#   'time',
#   'it’s',
#   'little',
#   'different',
#   'obviously',
#   'read',
#   'episode',
#   'honesty',
#   'felt',
#   'little',
#   'dirty',
#   'afterwards',
#   'guy',
#   'feeling',
#   'rest',
#   'season',
#   'want',
#   'know',
#   'happens',
#   'wanna',
#   'wait',
#   'yes',
#   'understand',
#   'sub',
#   'i’m',
#   'shit',
#   'it’s',
#   'final',
#   'season',
#   'everything',
#   'different',
#   'wanted',
#   'get',
#   'pulse',
#   'everyone',
#   'feeling'],
#  ['longclaw', 'shattering'],
#  ['hbo', 'going', 'advertising'],
#  ['updated', 'betting', 'odds', 'rule', 'westeros'],
#  ['hbo',
#   'release',
#   'tv',
#   'spot',
#   'dark',
#   'freefolk',
#   'dany',
#   'dragonstone',
#   'omg',
#   'hbo'],
#  ['last', 'night', 'leak', 'dark', 'full', 'shipping', 'video', 'min'],
#  ['sansa', 'right', 'whole', 'time'],
#  ['dany',
#   'leaving',
#   'winterfell',
#   'find',
#   'rightful',
#   'heir',
#   'iron',
#   'throne'],
#  ['dying', 'break', 'heart', 'season'],
#  ['dany', 'skinny', 'pregnant', 'queen'],
#  ['lady', 'sansa', 'daenerys', 'stormborn', 'fun', 'winterfell'],
#  ['day', 'third', 'quote', 'day'],
#  ['upvote', 'king', 'shit'],
#  ['long', 'claw', 'shatter', 'mean', 'certain', 'leaker', 'legit'],
#  ['think',
#   'many',
#   'folk',
#   'sleep',
#   'much',
#   'badass',
#   'jorah',
#   'mormont',
#   'rewatch',
#   'reminded',
#   'season',
#   'episode',
#   '“mockingbird”',
#   'fought',
#   'golden',
#   'company',
#   'elite',
#   'force',
#   'badass',
#   'sellswords'],
#  ['breaking', 'news', 'grrm', 'announces', 'wow', 'release', 'date'],
#  ['arya',
#   'marrying',
#   'genrdy',
#   'leaked',
#   'script',
#   'gendry',
#   'really',
#   'fell',
#   'love',
#   'way',
#   'wall',
#   'arya',
#   'know',
#   'prepared',
#   'everything',
#   'wedding',
#   'hereby',
#   'declare',
#   'husband',
#   'hot',
#   'pie'],
#  ['better', 'jump', 'arm', 'like', 'last', 'saw'],
#  ['winterfell', 'expansion', 'sapochnik', 'request'],
#  ['new', 'tv', 'spot', 'like'],
#  ['rewatching',
#   'couldn’t',
#   'help',
#   'notice',
#   'similarity',
#   'two',
#   'another',
#   'reason',
#   'arya',
#   'wasn’t',
#   'able',
#   'take',
#   'lady',
#   'crane'],
#  ['theory',
#   'home',
#   'sad',
#   'leak',
#   'boatsex',
#   'thing',
#   'beautiful',
#   'shoot',
#   'jon',
#   'daenerys',
#   'together',
#   'x',
#   'inception',
#   'need',
#   'share',
#   'i’m',
#   'freaking',
#   'boatsex',
#   'thing',
#   'tormenting',
#   'saw',
#   'single',
#   'sense',
#   'mean',
#   'jon',
#   'met',
#   'daenerys',
#   'episode',
#   'bang',
#   'episode',
#   'make',
#   'sense',
#   'it’s',
#   'develop',
#   'kind',
# ...
#   'com',
#   'production',
#   'diary',
#   'magic',
#   'leap',
#   'dead',
#   'must',
#   'die',
#   'http',
#   'www',
#   'makinggameofthrones',
#   'com',
#   'production',
#   'diary',
#   'magic',
#   'leap',
#   'dead',
#   'must',
#   'die'],
#  ['sophie',
#   'turner',
#   'say',
#   'took',
#   'paper',
#   'scroll',
#   'final',
#   'episode',
#   'souvenir',
#   'say',
#   'big',
#   'carry',
#   'wallet',
#   'could',
#   'would',
#   'receive'],
#  ['samuel', 'still', 'working', 'hard', 'becoming', 'maester'],
#  ['review', 'first', 'ep', 'premiere'],
#  ['prime', 'win'],
#  ['could', 'scene'],
#  ['guy',
#   'think',
#   'sansa',
#   'fighting',
#   'time',
#   'waiting',
#   'varys',
#   'winterfell'],
#  ['memo', 'hbo', 'intern'],
#  ['play', 'game', 'throne', 'either', 'win', 'die'],
#  ['throne',
#   'fantasy',
#   'back',
#   'final',
#   'season',
#   'hey',
#   'season',
#   'launched',
#   'got',
#   'fantasy',
#   'league',
#   'app',
#   'throne',
#   'fantasy',
#   'great',
#   'success',
#   'connecting',
#   'player',
#   'worldwide',
#   'back',
#   'eighth',
#   'final',
#   'season',
#   'new',
#   'character',
#   'bet',
#   'beautiful',
#   'new',
#   'dark',
#   'theme',
#   'website',
#   'http',
#   'thronefantasy',
#   'com',
#   'android',
#   'bit',
#   'ly',
#   'throne',
#   'fantasy',
#   'android',
#   'io',
#   'bit',
#   'ly',
#   'thronefantasy',
#   'work',
#   'create',
#   'team',
#   'favourite',
#   'character',
#   'within',
#   'certain',
#   'category',
#   'king',
#   'amp',
#   'queen',
#   'commander',
#   'etc',
#   'make',
#   'prediction',
#   'certain',
#   'thing',
#   'like',
#   'who’s',
#   'going',
#   'sit',
#   'iron',
#   'throne',
#   'end',
#   'season',
#   'many',
#   'chicken',
#   'going',
#   'eaten',
#   'team',
#   'ready',
#   'create',
#   'league',
#   'friend',
#   'colleague',
#   'etc',
#   'compete',
#   'point',
#   'episode',
#   'air',
#   'pick',
#   'scored',
#   'app',
#   'connects',
#   'facebook',
#   'see',
#   'pick',
#   'compare',
#   'friend',
#   'hope',
#   'guy',
#   'check',
#   'feel',
#   'free',
#   'let',
#   'know',
#   'feedback'],
#  ['reunion'],
#  ['you’re', 'suggesting', 'treason'],
#  ['carice', 'ny'],
#  ['spiral', 'symbol', 'hand', 'possible', 'foreshadowing'],
#  ['go', 'vote', 'arya', 'stark'],
#  ['coming'],
#  ['surprised',
#   'red',
#   'carpet',
#   'premiere',
#   'date',
#   'last',
#   'year',
#   'red',
#   'carpet',
#   'premiere',
#   'day',
#   'world',
#   'premiere',
#   'anyone',
#   'surprised',
#   'season',
#   'red',
#   'carpet',
#   'day',
#   'world',
#   'premiere',
#   'especially',
#   'since',
#   'last',
#   'season',
#   'guarded',
#   'ever'],
#  ['joe', 'dempsie', 'ny'],
#  ['thank',
#   'short',
#   'time',
#   'dedication',
#   'wealth',
#   'knowledge',
#   'insane',
#   'brought',
#   'news',
#   'trailer',
#   'date',
#   'dropped',
#   'kaysen',
#   'thank',
#   'last',
#   'promo',
#   'date',
#   'well',
#   'everytime',
#   'log',
#   'something',
#   'new',
#   'someone',
#   'found',
#   'whether',
#   'master',
#   'list',
#   'interview',
#   'week',
#   'next',
#   'social',
#   'medium',
#   'pic',
#   'red',
#   'carpet',
#   'premiere',
#   'tomorrow',
#   'night',
#   'stuff',
#   'promos',
#   'marketing',
#   'noticed',
#   'rabid',
#   'fan',
#   'since',
#   'lead',
#   'season',
#   'started',
#   'watching',
#   'show',
#   'little',
#   'season',
#   'finale',
#   'grateful',
#   'final',
#   'day',
#   'leading',
#   'final',
#   'season',
#   'thanks',
#   'everyone',
#   'thanks'],
#  ['like',
#   'husband',
#   'used',
#   'pat',
#   'back',
#   'realised',
#   'shame',
#   'never',
#   'got',
#   'scene',
#   'tywin',
#   'robert'],
#  ['yet',
#   'another',
#   'prediction',
#   'much',
#   'deliberation',
#   'wife',
#   'convinced',
#   'thing',
#   'jon',
#   'dany',
#   'body',
#   'upside',
#   'everyone',
#   'else',
#   'stark',
#   'flag',
#   'top',
#   'i’m',
#   'crazy',
#   'say',
#   'it’s',
#   'ned',
#   'can’t',
#   'see',
#   'ned’s',
#   'head',
#   'it’s',
#   'literally',
#   'top',
#   'central',
#   'figure',
#   'pic',
#   'that’s',
#   'guess',
#   'dammit'],
#  ['friend',
#   'made',
#   'chart',
#   'predict',
#   'character',
#   'death',
#   'among',
#   'thing',
#   'season',
#   'yes',
#   'upload',
#   'earlier',
#   'made',
#   'tweak',
#   'improvement',
#   'since'],
#  ['sophie',
#   'turner',
#   'already',
#   'hotel',
#   'cast',
#   'http',
#   'radikal',
#   'ru',
#   'b',
#   'bb',
#   'jpg',
#   'look',
#   'like',
#   'everyone',
#   'need',
#   'hotel',
#   'invited',
#   'premiere'],
#  ['kind',
#   'petition',
#   'exile',
#   'certain',
#   'fucked',
#   'user',
#   'talking',
#   'person',
#   'straight',
#   'enter',
#   'profile',
#   'read',
#   'latest',
#   'conversation',
#   'go',
#   'around',
#   'insulting',
#   'people',
#   'user',
#   'around',
#   'emilia',
#   'clarke',
#   'maisie',
#   'williams',
#   'claiming',
#   'love',
#   'hurt',
#   'people',
#   'emotionally',
#   'see',
#   'break',
#   'belong',
#   'sub',
#   'belong',
#   'near',
#   'internet',
#   'honest',
#   'obviously',
#   'potential',
#   'troll',
#   'know',
#   'chief',
#   'one'],
#  ['could',
#   'another',
#   'sex',
#   'scene',
#   'happen',
#   'jon',
#   'dany',
#   'dragonstone',
#   'episode'],
#  ['game', 'throne', 'round', 'sweet', 'open', 'link', 'vote', 'comment'],
#  ['began'],
#  ['new',
#   'iain',
#   'glen',
#   'interview',
#   'jorahs',
#   'fate',
#   'emilia',
#   'health',
#   'problem',
#   'http',
#   'www',
#   'com',
#   'game',
#   'throne',
#   'star',
#   'iain',
#   'glen',
#   'say',
#   'co',
#   'star',
#   'emilia',
#   'clarke',
#   'went',
#   'mill',
#   'aneurysm'],
#  ['finger', 'bum', 'laughed', 'hard'],
#  ['wish',
#   'friki',
#   'one',
#   'episode',
#   'episode',
#   'two',
#   'would',
#   'help',
#   'u',
#   'put',
#   'arc',
#   'season',
#   'better',
#   'context',
#   'leak',
#   'far',
#   'hit',
#   'u',
#   'multiple',
#   'episode'],
#  ['come',
#   'kill',
#   'stannis',
#   'blackwater',
#   'battle',
#   'watched',
#   'show',
#   'several',
#   'time',
#   'question',
#   'dawned',
#   'upon',
#   'ever',
#   'addressed',
#   'book',
#   'never',
#   'sailed',
#   'dragonstone',
#   'killed',
#   'stannis',
#   'defeated',
#   'blackwater',
#   'bay',
#   'could',
#   'used',
#   'fleet',
#   'used',
#   'battle',
#   'gone',
#   'lost',
#   'force',
#   'dragonstone',
#   'would',
#   'likely',
#   'fall',
#   'pretty',
#   'fast',
#   'obviously',
#   'considered',
#   'soundly',
#   'defeated',
#   'longer',
#   'threat',
#   'still',
#   'enemy',
#   'crown',
#   'seems',
#   'unlike',
#   'tywin',
#   'leave',
#   'enemy',
#   'around',
#   'curious',
#   'reasoning',
#   'book',
#   'ever',
#   'considered',
#   'attacking',
#   'besieging',
#   'dragonstone'],
#  ['red',
#   'dead',
#   'redemption',
#   'type',
#   'ending',
#   'possible',
#   'game',
#   'red',
#   'dead',
#   'redemption',
#   'ahead',
#   'amp',
#   'xb',
#   'don´t',
#   'know',
#   'many',
#   'played',
#   'game',
#   'im',
#   'gonna',
#   'summarize',
#   'main',
#   'character',
#   'dy',
#   'ending',
#   'epilogue',
#   'son',
#   'revenge',
#   'year',
#   'could',
#   'jon',
#   'daenerys',
#   'die',
#   'child',
#   'make',
#   'justice',
#   'future',
#   'amp',
#   'xb',
#   'opinion',
#   'totally',
#   'possible',
#   'last',
#   'enemy',
#   'cersei',
#   'since',
#   'think',
#   'night',
#   'king',
#   'real',
#   'thing',
#   'cant',
#   'see',
#   'happening',
#   'amp',
#   'xb'],
#  ['kit', 'snl', 'promo'],
#  ['sophie',
#   'turner',
#   'almost',
#   'spoiled',
#   'something',
#   '“and',
#   'took',
#   'scroll',
#   'like',
#   'one',
#   'last',
#   'episode',
#   'it’s',
#   'like',
#   'huge',
#   '”',
#   'sophie',
#   'turner',
#   'amp',
#   'xb',
#   'sophie',
#   'start',
#   'saying',
#   '“the',
#   'last',
#   'episode”',
#   'correct',
#   'maisie',
#   'stop',
#   'nodding',
#   'suddenly',
#   'seems',
#   'surprised',
#   'scroll',
#   'last',
#   'episode',
#   'interesting',
#   'video'],
#  ['question',
#   'attending',
#   'premiere',
#   'aside',
#   'cast',
#   'crew',
#   'expect',
#   'leak',
#   'anything',
#   'ep'],
#  ['hey',
#   'finally',
#   'awake',
#   'wait',
#   'wrong',
#   'fantasy',
#   'franchise',
#   'dragon',
#   'anyway',
#   'day',
#   'ago',
#   'created',
#   'little',
#   'whatsapp',
#   'u',
#   'freefolk',
#   'discussing',
#   'sock',
#   'latest',
#   'trailer',
#   'pic',
#   'leak',
#   'theory',
#   'currently',
#   'always',
#   'welcome',
#   'rule',
#   'knee',
#   'rude',
#   'rule',
#   'two',
#   'anyway',
#   'link',
#   'join',
#   'u',
#   'mate',
#   'http',
#   'chat',
#   'whatsapp',
#   'com',
#   'http',
#   'chat',
#   'whatsapp',
#   'com'],
#  ['snl', 'posted', 'first', 'video', 'kit', 'rehearsal', 'started', 'today'],
#  ['big',
#   'character',
#   'death',
#   'make',
#   'leak',
#   'jon',
#   'dany',
#   'arya',
#   'bran',
#   'sansa',
#   'alive',
#   'end',
#   'big',
#   'character',
#   'death',
#   'would',
#   'cersei',
#   'jaime',
#   'tyrion',
#   'death',
#   'somewhat',
#   'expected',
#   'except',
#   'tyrion',
#   'main',
#   'character',
#   'except',
#   'lannisters',
#   'alive',
#   'well',
#   'good',
#   'way',
#   'hand',
#   'lack',
#   'holy',
#   'shit',
#   'feeling',
#   'robb',
#   'ned',
#   'like',
#   'death',
#   'came',
#   'feel',
#   'like',
#   'lot',
#   'main',
#   'character',
#   'fully',
#   'safe',
#   'atm',
#   'thing',
#   'show',
#   'feeling',
#   'uncertainty',
#   'first',
#   'season',
#   'gave',
#   'season',
#   'lacked',
#   'expected',
#   'season',
#   'lack',
#   'well',
#   'episode',
#   'biggest',
#   'battle',
#   'show',
#   'feel',
#   'like',
#   'would',
#   'little',
#   'unrealistic',
#   'character',
#   'like',
#   'pod',
#   'jorah',
#   'die',
#   'mean',
#   'like',
#   'jorah',
#   'seeing',
#   'die',
#   'would',
#   'suck',
#   'feeling',
#   'compare',
#   'loss',
#   'someone',
#   'like',
#   'sam',
#   'seems',
#   'one',
#   'safe',
#   'character',
#   'even',
#   'tho',
#   'one',
#   'main',
#   'character',
#   'big',
#   'death',
#   'previous',
#   'season',
#   'big',
#   'main',
#   'character',
#   'died',
#   'died',
#   'unexpected',
#   'condition',
#   'death',
#   'seven',
#   'somehow',
#   'expected',
#   'expected',
#   'thoros',
#   'die',
#   'beyond',
#   'wall',
#   'situation',
#   'probably',
#   'high',
#   'bite',
#   'dust',
#   'battle',
#   'winterfell',
#   'expect',
#   'let',
#   'say',
#   'sansa',
#   'die',
#   'put',
#   'character',
#   'situation',
#   'take',
#   'narrative',
#   'vision',
#   'first',
#   'season',
#   'sure',
#   'even',
#   'jon',
#   'survives',
#   'mind',
#   'whinging',
#   'adore',
#   'show',
#   'think',
#   'mile',
#   'ahead',
#   'everything',
#   'else',
#   'ever',
#   'seen',
#   'wanted',
#   'share',
#   'thought',
#   'see',
#   'people',
#   'feel'],
#  ['jon', 'charging', 'battle', 'trailer'],
#  ['sansa’s',
#   'fan',
#   'right',
#   'feather',
#   'sansa',
#   'feather',
#   'frozen',
#   'nk',
#   'stark',
#   'teaser',
#   'feather',
#   'one',
#   'detail',
#   'fall',
#   'tower',
#   'new',
#   'teaser',
#   'feather',
#   'fall',
#   'lyanna’s',
#   'hand',
#   'theory',
#   'mean',
#   'don’t',
#   'think',
#   'feather',
#   'sansa'],
#  ['finger', 'bum', 'king', 'castle', 'new', 'york', 'press', 'stuff'],
#  ['daily',
#   'express',
#   'url',
#   'promo',
#   'pic',
#   'size',
#   'know',
#   'common',
#   'website',
#   'programming',
#   'savvy',
#   'noticed',
#   'sometimes',
#   'changing',
#   'thing',
#   'two',
#   'image',
#   'url',
#   'get',
#   'bigger',
#   'size',
#   'twitter',
#   'easiest',
#   'add',
#   'go',
#   'whenever',
#   'see',
#   'number',
#   'remove',
#   'everything',
#   'end',
#   'link',
#   'say',
#   'jpg',
#   'sometimes',
#   'complicated',
#   'replace',
#   'size',
#   'number',
#   'replace',
#   'word',
#   'give',
#   'example',
#   'quite',
#   'remember',
#   'one',
#   'belfast',
#   'paper',
#   'pic',
#   'looked',
#   'another',
#   'bigger',
#   'pic',
#   'replaced',
#   'word',
#   'binary',
#   'mean',
#   'getting',
#   'better',
#   'quality',
#   'url',
#   'fuckery',
#   'might',
#   'possibly',
#   'doable',
#   'idea',
#   'anyone',
#   'savvy',
#   'thing',
#   'might',
#   'idea',
#   'change',
#   'example',
#   'http',
#   'cdn',
#   'image',
#   'express',
#   'co',
#   'uk',
#   'img',
#   'dynamic',
#   'x',
#   'secondary',
#   'game',
#   'throne',
#   'season',
#   'picture',
#   'daenerys',
#   'jorah',
#   'jpg',
#   'pic',
#   'x',
#   'x',
#   'url',
#   'changing',
#   'give',
#   'error',
#   'changing',
#   'secondary',
#   'binary',
#   'give',
#   'error',
#   'well',
#   'idea'],
#  ['sell', 'kidney', 'get', 'ending'],
#  ['brain', 'everytime', 'take', 'forever', 'post', 'sub'],
#  ['omg', 'emotional', 'image', 'ridiculous'],
#  ['pressure',
#   'sapochnik',
#   'many',
#   'upset',
#   'worried',
#   'news',
#   'broke',
#   'available',
#   'season',
#   'thought',
#   'taylor',
#   'fine',
#   'job',
#   'spoil',
#   'war',
#   'hype',
#   'battle',
#   'winterfell',
#   'much',
#   'pressure',
#   'sapochnik',
#   'deliver',
#   'think',
#   'something',
#   'truly',
#   'amazing'],
#  ['together',
#   'despite',
#   'difference',
#   'fighting',
#   'common',
#   'enemy',
#   'cave',
#   'scene',
#   'foreshadowing',
#   'x'],
#  ['take'],
#  ['shield',
#   'question',
#   'who’s',
#   'sigil',
#   'shield',
#   'top',
#   'left',
#   'looked',
#   'vale',
#   'house',
#   'wikia',
#   'realm',
#   'googled',
#   'second',
#   'son',
#   'golden',
#   'company',
#   'etc',
#   'couldn’t',
#   'find',
#   'matching',
#   'two',
#   'bottom',
#   'look',
#   'like',
#   'unsullied',
#   'top',
#   'left',
#   'lannister'],
#  ['wore', 'best'],
#  ['carice', 'van', 'houten', 'interview', 'build'],
#  ['know',
#   'everyone',
#   'want',
#   'expects',
#   'sansa',
#   'dany',
#   'conflict',
#   'compliant',
#   'non',
#   'body',
#   'language',
#   'look',
#   'like',
#   'soldier',
#   'standing',
#   'parade',
#   'rest',
#   'awaiting',
#   'order',
#   'superior',
#   'officer'],
#  ['film',
#   'king',
#   'landing',
#   'set',
#   'know',
#   'built',
#   'huge',
#   'set',
#   'meant',
#   'street',
#   'king',
#   'landing',
#   'city',
#   'wall',
#   'jon',
#   'arya',
#   'filmed',
#   'unsullied',
#   'dothraki',
#   'extra',
#   'fire',
#   'dragon',
#   'present',
#   'surprisingly',
#   'white',
#   'walker',
#   'amp',
#   'xb',
#   'wtf',
#   'happened',
#   'seems',
#   'like',
#   'stark',
#   'targ',
#   'army',
#   'bust',
#   'king',
#   'landing',
#   'charge',
#   'red',
#   'keep',
#   'presumably',
#   'take',
#   'cersei',
#   'like',
#   'context',
#   'night',
#   'king',
#   'defeated',
#   'jon',
#   'seemingly',
#   'sacking',
#   'city',
#   'tf',
#   'daenerys'],
#  ['winter', 'coming', 'sir', 'ben'],
#  ['new',
#   'request',
#   'offer',
#   'open',
#   'call',
#   'anyone',
#   'provide',
#   'please',
#   'name',
#   'price',
#   'obo',
#   'proof',
#   'image',
#   'capture',
#   'required',
#   'paypal',
#   'bitcoin',
#   'transfer',
#   'serious',
#   'inquiry',
#   'private',
#   'message',
#   'regard',
#   'offer',
#   'stated',
#   'response',
#   'made',
#   'open',
#   'forum',
#   'offer',
#   'stand',
#   'hour',
#   'prior',
#   'airtime',
#   'condition',
#   'form',
#   'proof',
#   'regard',
#   'available',
#   'please',
#   'advise',
#   'private',
#   'message'],
#  ['new',
#   'tuber',
#   'stumbled',
#   'video',
#   'pretty',
#   'good',
#   'like',
#   'rational',
#   'non',
#   'fleaker',
#   'nonsense',
#   'review',
#   'love',
#   'accent'],
#  ['wonder',
#   'first',
#   'episode',
#   'title',
#   'revealed',
#   'tonight',
#   'right',
#   'guess',
#   'think',
#   'anything',
#   'except',
#   'something',
#   'really',
#   'bland',
#   'like',
#   'begin',
#   'suspect',
#   'something',
#   'interesting'],
#  ['many',
#   'people',
#   'think',
#   'die',
#   'battle',
#   'u',
#   'feel',
#   'night',
#   'king',
#   'steamroll',
#   'living',
#   'winterfell',
#   'walker',
#   'victorious',
#   'question',
#   'many',
#   'living',
#   'think',
#   'killed',
#   'think'],
#  ['euron', 'gonna', 'kill', 'cerseis', 'kid'],
#  ['there’s',
#   'one',
#   'thing',
#   'got',
#   'taught',
#   'it’s',
#   'pay',
#   'attention',
#   'parallel',
#   'also',
#   'people',
#   'think',
#   'they’re',
#   'really',
#   'smart',
#   'never',
#   'smart',
#   'think'],
#  ['eff',
#   'could',
#   'jaime’s',
#   'hand',
#   'it’s',
#   'right',
#   'hand',
#   'one',
#   'lost',
#   'golden',
#   'replacement',
#   'longer',
#   'isn’t'],
#  ['funny', 'feel', 'sorry', 'kid', 'can’t', 'experience', 'got'],
#  ['gwendoline', 'christie', 'ny'],
#  ['snl',
#   'posted',
#   'pic',
#   'iron',
#   'throne',
#   'outside',
#   'rockefeller',
#   'plaza',
#   'going',
#   'got',
#   'sketch',
#   'snl',
#   'week'],
#  ['year',
#   'ago',
#   'went',
#   'bobby',
#   'b',
#   'halloween',
#   'printed',
#   'crown',
#   'bought',
#   'buddy',
#   'painted'],
#  ['we’re', 'ready'],
#  ['snl',
#   'posted',
#   'pic',
#   'iron',
#   'throne',
#   'outside',
#   'plaza',
#   'going',
#   'got',
#   'kit',
#   'hosting',
#   'cast',
#   'nyc'],
#  ['word'],
#  ['there’s',
#   'theory',
#   'going',
#   'around',
#   'night',
#   'king',
#   'kill',
#   'reanimate',
#   'bran',
#   'lead',
#   'real',
#   'possibility',
#   'season',
#   'see',
#   'nk'],
#  ['guy', 'poster', 'everything'],
#  ['carice',
#   'van',
#   'houten',
#   'discus',
#   'final',
#   'season',
#   'hbo',
#   'game',
#   'throne'],
#  ['day',
#   'game',
#   'throne',
#   'season',
#   'th',
#   'day',
#   'winter',
#   'hbo',
#   'gave',
#   'army',
#   'coming',
#   'spider',
#   'spying',
#   'lord',
#   'leaving',
#   'fight',
#   'advancing',
#   'season',
#   'ending',
#   'sword',
#   'swinging',
#   'house',
#   'slaying',
#   'de',
#   'ad',
#   'starks',
#   'northward',
#   'dragon',
#   'incest',
#   'love',
#   'army',
#   'ice',
#   'zombie'],
#  ['year',
#   'old',
#   'grrm',
#   'would',
#   'agree',
#   'claim',
#   'white',
#   'walker',
#   'defeated',
#   'winterfell',
#   'would',
#   'anti',
#   'climatic'],
#  ...]

# %%
extra_stop_words = ['ign', 'diggory', 'cedric', 'timon', 'pumba', 'arnold', 'gotzmilk', 'episode', 'season', 'character', 'show', 
                    'amp', 'xb', 'de', 'et', 'le', 'http', 'la', 'com', 'il', 'de', 'gt', 'se', 'gt', 'qui', 'lt', 'xb', 'amp',
                   'one', 'would', 'could', 'gif', "youl'", 'may', 'get', 'instagram', 'aa',
 'aaa',
 'aaaaaaand',
 'aaaaand',
 'aaaand',
 'aaand',
 'aabns',
 'aabxbmaea',
 'aafdadceaf',
 'aarambha',
 'aaron',
 'aarya',
 'ab', 'abc', 'er', 'nk', 'ww', 'amp', 'http', 'asoiaf', 'com', 'reddit', 'www', 'subscriber', 'search', 'timestamp','gt', 'agot', 'adwd', 'character', 'like', 'book', 'season', 'episode',
                   'nbsp', 'http', 'com', 'tumblr',  'www', 'gif', 'asoiaf', 'comment', 'reddit', 'xb', 'amp', 'redd', 'png', 'http', 'like']

# %%
further_cleaned_corpus_freefolk = []
for document in cleaned_corpus_freefolk:
    further_cleaned_corpus_freefolk.append([word for word in document if word not in extra_stop_words])

# %%
pickle.dump(further_cleaned_corpus_freefolk, open("further_cleaned_corpus_freefolk.pkl", "wb" ) )

# %%
final_freefolk = []

for item in further_cleaned_corpus_freefolk:
    item = ' '.join(item)
    final_freefolk.append(item)

# %%
pickle.dump(final_freefolk, open("final_freefolk.pkl", "wb" ))
